# %% [markdown]
# ## Sending requests
#
# 200: Success!
#
# 401: Unauthorized client error status: lack of valid authentication credentials
#
# 403: The server understood the request but refuses to authorize it

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code) 

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
response
# Out:
# <Response [200]>

# %%
resp_json = response.json()

# %%
resp_json
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
#   'completed': True},
#  {'userId': 1,
#   'id': 11,
#   'title': 'vero rerum temporibus dolor',
#   'completed': True},
#  {'userId': 1,
#   'id': 12,
#   'title': 'ipsa repellendus fugit nisi',
#   'completed': True},
#  {'userId': 1, 'id': 13, 'title': 'et doloremque nulla', 'completed': False},
#  {'userId': 1,
#   'id': 14,
#   'title': 'repellendus sunt dolores architecto voluptatum',
#   'completed': True},
#  {'userId': 1,
#   'id': 15,
#   'title': 'ab voluptatum amet voluptas',
#   'completed': True},
#  {'userId': 1,
#   'id': 16,
#   'title': 'accusamus eos facilis sint et aut voluptatem',
#   'completed': True},
#  {'userId': 1,
#   'id': 17,
#   'title': 'quo laboriosam deleniti aut qui',
#   'completed': True},
#  {'userId': 1,
#   'id': 18,
#   'title': 'dolorum est consequatur ea mollitia in culpa',
#   'completed': False},
#  {'userId': 1,
#   'id': 19,
#   'title': 'molestiae ipsa aut voluptatibus pariatur dolor nihil',
#   'completed': True},
#  {'userId': 1,
#   'id': 20,
#   'title': 'ullam nobis libero sapiente ad optio sint',
#   'completed': True},
#  {'userId': 2,
#   'id': 21,
#   'title': 'suscipit repellat esse quibusdam voluptatem incidunt',
#   'completed': False},
#  {'userId': 2,
#   'id': 22,
#   'title': 'distinctio vitae autem nihil ut molestias quo',
#   'completed': True},
#  {'userId': 2,
#   'id': 23,
#   'title': 'et itaque necessitatibus maxime molestiae qui quas velit',
#   'completed': False},
#  {'userId': 2,
#   'id': 24,
#   'title': 'adipisci non ad dicta qui amet quaerat doloribus ea',
#   'completed': False},
#  {'userId': 2,
#   'id': 25,
#   'title': 'voluptas quo tenetur perspiciatis explicabo natus',
#   'completed': True},
#  {'userId': 2, 'id': 26, 'title': 'aliquam aut quasi', 'completed': True},
#  {'userId': 2,
#   'id': 27,
#   'title': 'veritatis pariatur delectus',
#   'completed': True},
#  {'userId': 2,
#   'id': 28,
#   'title': 'nesciunt totam sit blanditiis sit',
#   'completed': False},
#  {'userId': 2, 'id': 29, 'title': 'laborum aut in quam', 'completed': False},
#  {'userId': 2,
#   'id': 30,
#   'title': 'nemo perspiciatis repellat ut dolor libero commodi blanditiis omnis',
#   'completed': True},
#  {'userId': 2,
#   'id': 31,
#   'title': 'repudiandae totam in est sint facere fuga',
#   'completed': False},
#  {'userId': 2,
#   'id': 32,
#   'title': 'earum doloribus ea doloremque quis',
#   'completed': False},
#  {'userId': 2, 'id': 33, 'title': 'sint sit aut vero', 'completed': False},
#  {'userId': 2,
#   'id': 34,
#   'title': 'porro aut necessitatibus eaque distinctio',
#   'completed': False},
#  {'userId': 2,
#   'id': 35,
#   'title': 'repellendus veritatis molestias dicta incidunt',
#   'completed': True},
#  {'userId': 2,
#   'id': 36,
#   'title': 'excepturi deleniti adipisci voluptatem et neque optio illum ad',
#   'completed': True},
#  {'userId': 2, 'id': 37, 'title': 'sunt cum tempora', 'completed': False},
#  {'userId': 2, 'id': 38, 'title': 'totam quia non', 'completed': False},
#  {'userId': 2,
#   'id': 39,
#   'title': 'doloremque quibusdam asperiores libero corrupti illum qui omnis',
#   'completed': False},
#  {'userId': 2,
#   'id': 40,
#   'title': 'totam atque quo nesciunt',
#   'completed': True},
#  {'userId': 3,
#   'id': 41,
#   'title': 'aliquid amet impedit consequatur aspernatur placeat eaque fugiat suscipit',
#   'completed': False},
#  {'userId': 3,
#   'id': 42,
#   'title': 'rerum perferendis error quia ut eveniet',
#   'completed': False},
#  {'userId': 3,
#   'id': 43,
#   'title': 'tempore ut sint quis recusandae',
#   'completed': True},
#  {'userId': 3,
#   'id': 44,
#   'title': 'cum debitis quis accusamus doloremque ipsa natus sapiente omnis',
#   'completed': True},
#  {'userId': 3,
#   'id': 45,
#   'title': 'velit soluta adipisci molestias reiciendis harum',
#   'completed': False},
#  {'userId': 3,
#   'id': 46,
#   'title': 'vel voluptatem repellat nihil placeat corporis',
#   'completed': False},
#  {'userId': 3,
#   'id': 47,
#   'title': 'nam qui rerum fugiat accusamus',
#   'completed': False},
#  {'userId': 3,
#   'id': 48,
#   'title': 'sit reprehenderit omnis quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 49,
#   'title': 'ut necessitatibus aut maiores debitis officia blanditiis velit et',
#   'completed': False},
#  {'userId': 3,
#   'id': 50,
#   'title': 'cupiditate necessitatibus ullam aut quis dolor voluptate',
#   'completed': True},
#  {'userId': 3,
#   'id': 51,
#   'title': 'distinctio exercitationem ab doloribus',
#   'completed': False},
#  {'userId': 3,
#   'id': 52,
#   'title': 'nesciunt dolorum quis recusandae ad pariatur ratione',
#   'completed': False},
#  {'userId': 3,
#   'id': 53,
#   'title': 'qui labore est occaecati recusandae aliquid quam',
#   'completed': False},
#  {'userId': 3,
#   'id': 54,
#   'title': 'quis et est ut voluptate quam dolor',
#   'completed': True},
#  {'userId': 3,
#   'id': 55,
#   'title': 'voluptatum omnis minima qui occaecati provident nulla voluptatem ratione',
#   'completed': True},
#  {'userId': 3,
#   'id': 56,
#   'title': 'deleniti ea temporibus enim',
#   'completed': True},
#  {'userId': 3,
#   'id': 57,
#   'title': 'pariatur et magnam ea doloribus similique voluptatem rerum quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 58,
#   'title': 'est dicta totam qui explicabo doloribus qui dignissimos',
#   'completed': False},
#  {'userId': 3,
#   'id': 59,
#   'title': 'perspiciatis velit id laborum placeat iusto et aliquam odio',
#   'completed': False},
#  {'userId': 3,
#   'id': 60,
#   'title': 'et sequi qui architecto ut adipisci',
#   'completed': True},
#  {'userId': 4,
#   'id': 61,
#   'title': 'odit optio omnis qui sunt',
#   'completed': True},
#  {'userId': 4,
#   'id': 62,
#   'title': 'et placeat et tempore aspernatur sint numquam',
#   'completed': False},
#  {'userId': 4,
#   'id': 63,
#   'title': 'doloremque aut dolores quidem fuga qui nulla',
#   'completed': True},
#  {'userId': 4,
#   'id': 64,
#   'title': 'voluptas consequatur qui ut quia magnam nemo esse',
#   'completed': False},
#  {'userId': 4,
#   'id': 65,
#   'title': 'fugiat pariatur ratione ut asperiores necessitatibus magni',
#   'completed': False},
#  {'userId': 4,
#   'id': 66,
#   'title': 'rerum eum molestias autem voluptatum sit optio',
#   'completed': False},
#  {'userId': 4,
#   'id': 67,
#   'title': 'quia voluptatibus voluptatem quos similique maiores repellat',
#   'completed': False},
#  {'userId': 4,
#   'id': 68,
#   'title': 'aut id perspiciatis voluptatem iusto',
#   'completed': False},
#  {'userId': 4,
#   'id': 69,
#   'title': 'doloribus sint dolorum ab adipisci itaque dignissimos aliquam suscipit',
#   'completed': False},
#  {'userId': 4,
#   'id': 70,
#   'title': 'ut sequi accusantium et mollitia delectus sunt',
#   'completed': False},
#  {'userId': 4, 'id': 71, 'title': 'aut velit saepe ullam', 'completed': False},
#  {'userId': 4,
#   'id': 72,
#   'title': 'praesentium facilis facere quis harum voluptatibus voluptatem eum',
#   'completed': False},
#  {'userId': 4,
#   'id': 73,
#   'title': 'sint amet quia totam corporis qui exercitationem commodi',
#   'completed': True},
#  {'userId': 4,
#   'id': 74,
#   'title': 'expedita tempore nobis eveniet laborum maiores',
#   'completed': False},
#  {'userId': 4,
#   'id': 75,
#   'title': 'occaecati adipisci est possimus totam',
#   'completed': False},
#  {'userId': 4, 'id': 76, 'title': 'sequi dolorem sed', 'completed': True},
#  {'userId': 4,
#   'id': 77,
#   'title': 'maiores aut nesciunt delectus exercitationem vel assumenda eligendi at',
#   'completed': False},
#  {'userId': 4,
#   'id': 78,
#   'title': 'reiciendis est magnam amet nemo iste recusandae impedit quaerat',
#   'completed': False},
#  {'userId': 4, 'id': 79, 'title': 'eum ipsa maxime ut', 'completed': True},
#  {'userId': 4,
#   'id': 80,
#   'title': 'tempore molestias dolores rerum sequi voluptates ipsum consequatur',
#   'completed': True},
#  {'userId': 5, 'id': 81, 'title': 'suscipit qui totam', 'completed': True},
#  {'userId': 5,
#   'id': 82,
#   'title': 'voluptates eum voluptas et dicta',
#   'completed': False},
#  {'userId': 5,
#   'id': 83,
#   'title': 'quidem at rerum quis ex aut sit quam',
#   'completed': True},
#  {'userId': 5,
#   'id': 84,
#   'title': 'sunt veritatis ut voluptate',
#   'completed': False},
#  {'userId': 5, 'id': 85, 'title': 'et quia ad iste a', 'completed': True},
#  {'userId': 5,
#   'id': 86,
#   'title': 'incidunt ut saepe autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 87,
#   'title': 'laudantium quae eligendi consequatur quia et vero autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 88,
#   'title': 'vitae aut excepturi laboriosam sint aliquam et et accusantium',
#   'completed': False},
#  {'userId': 5, 'id': 89, 'title': 'sequi ut omnis et', 'completed': True},
#  {'userId': 5,
#   'id': 90,
#   'title': 'molestiae nisi accusantium tenetur dolorem et',
#   'completed': True},
#  {'userId': 5,
#   'id': 91,
#   'title': 'nulla quis consequatur saepe qui id expedita',
#   'completed': True},
#  {'userId': 5, 'id': 92, 'title': 'in omnis laboriosam', 'completed': True},
#  {'userId': 5,
#   'id': 93,
#   'title': 'odio iure consequatur molestiae quibusdam necessitatibus quia sint',
#   'completed': True},
#  {'userId': 5,
#   'id': 94,
#   'title': 'facilis modi saepe mollitia',
#   'completed': False},
#  {'userId': 5,
#   'id': 95,
#   'title': 'vel nihil et molestiae iusto assumenda nemo quo ut',
#   'completed': True},
#  {'userId': 5,
#   'id': 96,
#   'title': 'nobis suscipit ducimus enim asperiores voluptas',
#   'completed': False},
#  {'userId': 5,
#   'id': 97,
#   'title': 'dolorum laboriosam eos qui iure aliquam',
#   'completed': False},
#  {'userId': 5,
#   'id': 98,
#   'title': 'debitis accusantium ut quo facilis nihil quis sapiente necessitatibus',
#   'completed': True},
#  {'userId': 5,
#   'id': 99,
#   'title': 'neque voluptates ratione',
#   'completed': False},
#  {'userId': 5,
#   'id': 100,
#   'title': 'excepturi a et neque qui expedita vel voluptate',
#   'completed': False},
#  {'userId': 6,
#   'id': 101,
#   'title': 'explicabo enim cumque porro aperiam occaecati minima',
#   'completed': False},
#  {'userId': 6, 'id': 102, 'title': 'sed ab consequatur', 'completed': False},
#  {'userId': 6,
#   'id': 103,
#   'title': 'non sunt delectus illo nulla tenetur enim omnis',
#   'completed': False},
#  {'userId': 6,
#   'id': 104,
#   'title': 'excepturi non laudantium quo',
#   'completed': False},
#  {'userId': 6,
#   'id': 105,
#   'title': 'totam quia dolorem et illum repellat voluptas optio',
#   'completed': True},
#  {'userId': 6,
#   'id': 106,
#   'title': 'ad illo quis voluptatem temporibus',
#   'completed': True},
#  {'userId': 6,
#   'id': 107,
#   'title': 'praesentium facilis omnis laudantium fugit ad iusto nihil nesciunt',
#   'completed': False},
#  {'userId': 6,
#   'id': 108,
#   'title': 'a eos eaque nihil et exercitationem incidunt delectus',
#   'completed': True},
#  {'userId': 6,
#   'id': 109,
#   'title': 'autem temporibus harum quisquam in culpa',
#   'completed': True},
#  {'userId': 6, 'id': 110, 'title': 'aut aut ea corporis', 'completed': True},
#  {'userId': 6,
#   'id': 111,
#   'title': 'magni accusantium labore et id quis provident',
#   'completed': False},
#  {'userId': 6,
#   'id': 112,
#   'title': 'consectetur impedit quisquam qui deserunt non rerum consequuntur eius',
#   'completed': False},
#  {'userId': 6,
#   'id': 113,
#   'title': 'quia atque aliquam sunt impedit voluptatum rerum assumenda nisi',
#   'completed': False},
#  {'userId': 6,
#   'id': 114,
#   'title': 'cupiditate quos possimus corporis quisquam exercitationem beatae',
#   'completed': False},
#  {'userId': 6, 'id': 115, 'title': 'sed et ea eum', 'completed': False},
#  {'userId': 6,
#   'id': 116,
#   'title': 'ipsa dolores vel facilis ut',
#   'completed': True},
#  {'userId': 6,
#   'id': 117,
#   'title': 'sequi quae est et qui qui eveniet asperiores',
#   'completed': False},
#  {'userId': 6,
#   'id': 118,
#   'title': 'quia modi consequatur vero fugiat',
#   'completed': False},
#  {'userId': 6,
#   'id': 119,
#   'title': 'corporis ducimus ea perspiciatis iste',
#   'completed': False},
#  {'userId': 6,
#   'id': 120,
#   'title': 'dolorem laboriosam vel voluptas et aliquam quasi',
#   'completed': False},
#  {'userId': 7,
#   'id': 121,
#   'title': 'inventore aut nihil minima laudantium hic qui omnis',
#   'completed': True},
#  {'userId': 7,
#   'id': 122,
#   'title': 'provident aut nobis culpa',
#   'completed': True},
#  {'userId': 7,
#   'id': 123,
#   'title': 'esse et quis iste est earum aut impedit',
#   'completed': False},
#  {'userId': 7, 'id': 124, 'title': 'qui consectetur id', 'completed': False},
#  {'userId': 7,
#   'id': 125,
#   'title': 'aut quasi autem iste tempore illum possimus',
#   'completed': False},
#  {'userId': 7,
#   'id': 126,
#   'title': 'ut asperiores perspiciatis veniam ipsum rerum saepe',
#   'completed': True},
#  {'userId': 7,
#   'id': 127,
#   'title': 'voluptatem libero consectetur rerum ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 128,
#   'title': 'eius omnis est qui voluptatem autem',
#   'completed': False},
#  {'userId': 7,
#   'id': 129,
#   'title': 'rerum culpa quis harum',
#   'completed': False},
#  {'userId': 7,
#   'id': 130,
#   'title': 'nulla aliquid eveniet harum laborum libero alias ut unde',
#   'completed': True},
#  {'userId': 7, 'id': 131, 'title': 'qui ea incidunt quis', 'completed': False},
#  {'userId': 7,
#   'id': 132,
#   'title': 'qui molestiae voluptatibus velit iure harum quisquam',
#   'completed': True},
#  {'userId': 7,
#   'id': 133,
#   'title': 'et labore eos enim rerum consequatur sunt',
#   'completed': True},
#  {'userId': 7,
#   'id': 134,
#   'title': 'molestiae doloribus et laborum quod ea',
#   'completed': False},
#  {'userId': 7,
#   'id': 135,
#   'title': 'facere ipsa nam eum voluptates reiciendis vero qui',
#   'completed': False},
#  {'userId': 7,
#   'id': 136,
#   'title': 'asperiores illo tempora fuga sed ut quasi adipisci',
#   'completed': False},
#  {'userId': 7, 'id': 137, 'title': 'qui sit non', 'completed': False},
#  {'userId': 7,
#   'id': 138,
#   'title': 'placeat minima consequatur rem qui ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 139,
#   'title': 'consequatur doloribus id possimus voluptas a voluptatem',
#   'completed': False},
#  {'userId': 7,
#   'id': 140,
#   'title': 'aut consectetur in blanditiis deserunt quia sed laboriosam',
#   'completed': True},
#  {'userId': 8,
#   'id': 141,
#   'title': 'explicabo consectetur debitis voluptates quas quae culpa rerum non',
#   'completed': True},
#  {'userId': 8,
#   'id': 142,
#   'title': 'maiores accusantium architecto necessitatibus reiciendis ea aut',
#   'completed': True},
#  {'userId': 8,
#   'id': 143,
#   'title': 'eum non recusandae cupiditate animi',
#   'completed': False},
#  {'userId': 8,
#   'id': 144,
#   'title': 'ut eum exercitationem sint',
#   'completed': False},
#  {'userId': 8,
#   'id': 145,
#   'title': 'beatae qui ullam incidunt voluptatem non nisi aliquam',
#   'completed': False},
#  {'userId': 8,
#   'id': 146,
#   'title': 'molestiae suscipit ratione nihil odio libero impedit vero totam',
#   'completed': True},
#  {'userId': 8,
#   'id': 147,
#   'title': 'eum itaque quod reprehenderit et facilis dolor autem ut',
#   'completed': True},
#  {'userId': 8,
#   'id': 148,
#   'title': 'esse quas et quo quasi exercitationem',
#   'completed': False},
#  {'userId': 8,
#   'id': 149,
#   'title': 'animi voluptas quod perferendis est',
#   'completed': False},
#  {'userId': 8,
#   'id': 150,
#   'title': 'eos amet tempore laudantium fugit a',
#   'completed': False},
#  {'userId': 8,
#   'id': 151,
#   'title': 'accusamus adipisci dicta qui quo ea explicabo sed vero',
#   'completed': True},
#  {'userId': 8,
#   'id': 152,
#   'title': 'odit eligendi recusandae doloremque cumque non',
#   'completed': False},
#  {'userId': 8,
#   'id': 153,
#   'title': 'ea aperiam consequatur qui repellat eos',
#   'completed': False},
#  {'userId': 8, 'id': 154, 'title': 'rerum non ex sapiente', 'completed': True},
#  {'userId': 8,
#   'id': 155,
#   'title': 'voluptatem nobis consequatur et assumenda magnam',
#   'completed': True},
#  {'userId': 8,
#   'id': 156,
#   'title': 'nam quia quia nulla repellat assumenda quibusdam sit nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 157,
#   'title': 'dolorem veniam quisquam deserunt repellendus',
#   'completed': True},
#  {'userId': 8,
#   'id': 158,
#   'title': 'debitis vitae delectus et harum accusamus aut deleniti a',
#   'completed': True},
#  {'userId': 8,
#   'id': 159,
#   'title': 'debitis adipisci quibusdam aliquam sed dolore ea praesentium nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 160,
#   'title': 'et praesentium aliquam est',
#   'completed': False},
#  {'userId': 9,
#   'id': 161,
#   'title': 'ex hic consequuntur earum omnis alias ut occaecati culpa',
#   'completed': True},
#  {'userId': 9,
#   'id': 162,
#   'title': 'omnis laboriosam molestias animi sunt dolore',
#   'completed': True},
#  {'userId': 9,
#   'id': 163,
#   'title': 'natus corrupti maxime laudantium et voluptatem laboriosam odit',
#   'completed': False},
#  {'userId': 9,
#   'id': 164,
#   'title': 'reprehenderit quos aut aut consequatur est sed',
#   'completed': False},
#  {'userId': 9,
#   'id': 165,
#   'title': 'fugiat perferendis sed aut quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 166,
#   'title': 'quos quo possimus suscipit minima ut',
#   'completed': False},
#  {'userId': 9,
#   'id': 167,
#   'title': 'et quis minus quo a asperiores molestiae',
#   'completed': False},
#  {'userId': 9,
#   'id': 168,
#   'title': 'recusandae quia qui sunt libero',
#   'completed': False},
#  {'userId': 9,
#   'id': 169,
#   'title': 'ea odio perferendis officiis',
#   'completed': True},
#  {'userId': 9,
#   'id': 170,
#   'title': 'quisquam aliquam quia doloribus aut',
#   'completed': False},
#  {'userId': 9,
#   'id': 171,
#   'title': 'fugiat aut voluptatibus corrupti deleniti velit iste odio',
#   'completed': True},
#  {'userId': 9,
#   'id': 172,
#   'title': 'et provident amet rerum consectetur et voluptatum',
#   'completed': False},
#  {'userId': 9,
#   'id': 173,
#   'title': 'harum ad aperiam quis',
#   'completed': False},
#  {'userId': 9, 'id': 174, 'title': 'similique aut quo', 'completed': False},
#  {'userId': 9,
#   'id': 175,
#   'title': 'laudantium eius officia perferendis provident perspiciatis asperiores',
#   'completed': True},
#  {'userId': 9,
#   'id': 176,
#   'title': 'magni soluta corrupti ut maiores rem quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 177,
#   'title': 'et placeat temporibus voluptas est tempora quos quibusdam',
#   'completed': False},
#  {'userId': 9,
#   'id': 178,
#   'title': 'nesciunt itaque commodi tempore',
#   'completed': True},
#  {'userId': 9,
#   'id': 179,
#   'title': 'omnis consequuntur cupiditate impedit itaque ipsam quo',
#   'completed': True},
#  {'userId': 9,
#   'id': 180,
#   'title': 'debitis nisi et dolorem repellat et',
#   'completed': True},
#  {'userId': 10,
#   'id': 181,
#   'title': 'ut cupiditate sequi aliquam fuga maiores',
#   'completed': False},
#  {'userId': 10,
#   'id': 182,
#   'title': 'inventore saepe cumque et aut illum enim',
#   'completed': True},
#  {'userId': 10,
#   'id': 183,
#   'title': 'omnis nulla eum aliquam distinctio',
#   'completed': True},
#  {'userId': 10,
#   'id': 184,
#   'title': 'molestias modi perferendis perspiciatis',
#   'completed': False},
#  {'userId': 10,
#   'id': 185,
#   'title': 'voluptates dignissimos sed doloribus animi quaerat aut',
#   'completed': False},
#  {'userId': 10,
#   'id': 186,
#   'title': 'explicabo odio est et',
#   'completed': False},
#  {'userId': 10,
#   'id': 187,
#   'title': 'consequuntur animi possimus',
#   'completed': False},
#  {'userId': 10, 'id': 188, 'title': 'vel non beatae est', 'completed': True},
#  {'userId': 10,
#   'id': 189,
#   'title': 'culpa eius et voluptatem et',
#   'completed': True},
#  {'userId': 10,
#   'id': 190,
#   'title': 'accusamus sint iusto et voluptatem exercitationem',
#   'completed': True},
#  {'userId': 10,
#   'id': 191,
#   'title': 'temporibus atque distinctio omnis eius impedit tempore molestias pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 192,
#   'title': 'ut quas possimus exercitationem sint voluptates',
#   'completed': False},
#  {'userId': 10,
#   'id': 193,
#   'title': 'rerum debitis voluptatem qui eveniet tempora distinctio a',
#   'completed': True},
#  {'userId': 10,
#   'id': 194,
#   'title': 'sed ut vero sit molestiae',
#   'completed': False},
#  {'userId': 10,
#   'id': 195,
#   'title': 'rerum ex veniam mollitia voluptatibus pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 196,
#   'title': 'consequuntur aut ut fugit similique',
#   'completed': True},
#  {'userId': 10,
#   'id': 197,
#   'title': 'dignissimos quo nobis earum saepe',
#   'completed': True},
#  {'userId': 10,
#   'id': 198,
#   'title': 'quis eius est sint explicabo',
#   'completed': True},
#  {'userId': 10,
#   'id': 199,
#   'title': 'numquam repellendus a magnam',
#   'completed': True},
#  {'userId': 10,
#   'id': 200,
#   'title': 'ipsam aperiam voluptates qui',
#   'completed': False}]

# %%
import pandas as pd
# json to pandas dataframe
pd.DataFrame(resp_json)
# Out:
#      userId   id                                              title  completed
# 0         1    1                                 delectus aut autem      False
# 1         1    2                 quis ut nam facilis et officia qui      False
# 2         1    3                                fugiat veniam minus      False
# 3         1    4                                   et porro tempora       True
# 4         1    5  laboriosam mollitia et enim quasi adipisci qui...      False
# ..      ...  ...                                                ...        ...
# 195      10  196                consequuntur aut ut fugit similique       True
# 196      10  197                  dignissimos quo nobis earum saepe       True
# 197      10  198                       quis eius est sint explicabo       True
# 198      10  199                       numquam repellendus a magnam       True
# 199      10  200                       ipsam aperiam voluptates qui      False
#
# [200 rows x 4 columns]

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
requests.get("https://api.github.com/zen").text
# Out:
# 'Mind your words, they are important.'

# %%
response = requests.get('https://api.github.com/events')

# %%
# get the .json from the response

github_response = response.json()

# %%
github_response
# Out:
# [{'id': '19014689258',
#   'type': 'WatchEvent',
#   'actor': {'id': 8478977,
#    'login': 'akiyosi',
#    'display_login': 'akiyosi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/akiyosi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8478977?'},
#   'repo': {'id': 430243923,
#    'name': 'renerocksai/telekasten.nvim',
#    'url': 'https://api.github.com/repos/renerocksai/telekasten.nvim'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z'},
#  {'id': '19014689251',
#   'type': 'PushEvent',
#   'actor': {'id': 71103415,
#    'login': 'rjpagano',
#    'display_login': 'rjpagano',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rjpagano',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71103415?'},
#   'repo': {'id': 297516387,
#    'name': 'rjpagano/covid_19_counties',
#    'url': 'https://api.github.com/repos/rjpagano/covid_19_counties'},
#   'payload': {'push_id': 8453373995,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '4f9d4ed454fb803166b9b7fc2c64cf51032d6ff0',
#    'before': 'f07f44c5d654962ceb96c4b7d884b2ec872685a9',
#    'commits': [{'sha': '4f9d4ed454fb803166b9b7fc2c64cf51032d6ff0',
#      'author': {'email': '71103415+rjpagano@users.noreply.github.com',
#       'name': 'rjpagano'},
#      'message': 'daily update of us_county_Minnesota_Hennepin_deaths.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rjpagano/covid_19_counties/commits/4f9d4ed454fb803166b9b7fc2c64cf51032d6ff0'}]},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z'},
#  {'id': '19014689254',
#   'type': 'CreateEvent',
#   'actor': {'id': 83210854,
#    'login': 'CorentinNrd',
#    'display_login': 'CorentinNrd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CorentinNrd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83210854?'},
#   'repo': {'id': 431104983,
#    'name': 'CorentinNrd/Portfolio-Corentin',
#    'url': 'https://api.github.com/repos/CorentinNrd/Portfolio-Corentin'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Portfolio',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z'},
#  {'id': '19014689242',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 19505559,
#    'login': 'dmitryshelomanov',
#    'display_login': 'dmitryshelomanov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dmitryshelomanov',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19505559?'},
#   'repo': {'id': 51462299,
#    'name': 'jaredpalmer/razzle',
#    'url': 'https://api.github.com/repos/jaredpalmer/razzle'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/jaredpalmer/razzle/issues/1765',
#     'repository_url': 'https://api.github.com/repos/jaredpalmer/razzle',
#     'labels_url': 'https://api.github.com/repos/jaredpalmer/razzle/issues/1765/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/jaredpalmer/razzle/issues/1765/comments',
#     'events_url': 'https://api.github.com/repos/jaredpalmer/razzle/issues/1765/events',
#     'html_url': 'https://github.com/jaredpalmer/razzle/issues/1765',
#     'id': 1060653089,
#     'node_id': 'I_kwDOAxFAm84_OEgh',
#     'number': 1765,
#     'title': 'How to prepare font ?',
#     'user': {'login': 'dmitryshelomanov',
#      'id': 19505559,
#      'node_id': 'MDQ6VXNlcjE5NTA1NTU5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/19505559?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dmitryshelomanov',
#      'html_url': 'https://github.com/dmitryshelomanov',
#      'followers_url': 'https://api.github.com/users/dmitryshelomanov/followers',
#      'following_url': 'https://api.github.com/users/dmitryshelomanov/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dmitryshelomanov/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dmitryshelomanov/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dmitryshelomanov/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dmitryshelomanov/orgs',
#      'repos_url': 'https://api.github.com/users/dmitryshelomanov/repos',
#      'events_url': 'https://api.github.com/users/dmitryshelomanov/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dmitryshelomanov/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 7,
#     'created_at': '2021-11-22T22:28:58Z',
#     'updated_at': '2021-11-23T13:12:56Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': '![image](https://user-images.githubusercontent.com/19505559/142944417-d34daa08-43f1-45e8-8921-5dc6d727964a.png)\r\nfonts included ```module.exports = __webpack_public_path__ + "link-to-media-fonts";```\r\n\r\nbrowser cannot parse it\r\n\r\nhow to fix  ?\r\n\r\n(media contains normal ttf font and etc types)',
#     'reactions': {'url': 'https://api.github.com/repos/jaredpalmer/razzle/issues/1765/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/jaredpalmer/razzle/issues/1765/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/jaredpalmer/razzle/issues/comments/976513134',
#     'html_url': 'https://github.com/jaredpalmer/razzle/issues/1765#issuecomment-976513134',
#     'issue_url': 'https://api.github.com/repos/jaredpalmer/razzle/issues/1765',
#     'id': 976513134,
#     'node_id': 'IC_kwDOAxFAm846NGhu',
#     'user': {'login': 'dmitryshelomanov',
#      'id': 19505559,
#      'node_id': 'MDQ6VXNlcjE5NTA1NTU5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/19505559?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dmitryshelomanov',
#      'html_url': 'https://github.com/dmitryshelomanov',
#      'followers_url': 'https://api.github.com/users/dmitryshelomanov/followers',
#      'following_url': 'https://api.github.com/users/dmitryshelomanov/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dmitryshelomanov/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dmitryshelomanov/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dmitryshelomanov/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dmitryshelomanov/orgs',
#      'repos_url': 'https://api.github.com/users/dmitryshelomanov/repos',
#      'events_url': 'https://api.github.com/users/dmitryshelomanov/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dmitryshelomanov/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2021-11-23T13:12:56Z',
#     'updated_at': '2021-11-23T13:12:56Z',
#     'author_association': 'NONE',
#     'body': '![image](https://user-images.githubusercontent.com/19505559/143030281-44f95916-aac8-4c6a-8b6d-5607531be4b3.png)\r\n',
#     'reactions': {'url': 'https://api.github.com/repos/jaredpalmer/razzle/issues/comments/976513134/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z'},
#  {'id': '19014689285',
#   'type': 'PushEvent',
#   'actor': {'id': 93101859,
#    'login': 'Paul-Recamier',
#    'display_login': 'Paul-Recamier',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Paul-Recamier',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/93101859?'},
#   'repo': {'id': 421539033,
#    'name': 'TarekBEnsea/Projet2A.AntHill',
#    'url': 'https://api.github.com/repos/TarekBEnsea/Projet2A.AntHill'},
#   'payload': {'push_id': 8453374058,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '806bd7dc6f03ab87a136ad6b5cb50cf98da0d80e',
#    'before': 'bb0d8eb48672d4a62c0913bc1c1dfc1dd2b4bd06',
#    'commits': [{'sha': '23c00cabc0f52b1f734f8a4a146041b224f5ad52',
#      'author': {'email': 'paul.recamier@ensea.fr', 'name': 'Paul_Recamier'},
#      'message': 'Modif ressources',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/TarekBEnsea/Projet2A.AntHill/commits/23c00cabc0f52b1f734f8a4a146041b224f5ad52'},
#     {'sha': '806bd7dc6f03ab87a136ad6b5cb50cf98da0d80e',
#      'author': {'email': 'paul.recamier@ensea.fr', 'name': 'Paul_Recamier'},
#      'message': "Merge remote-tracking branch 'origin/master'",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/TarekBEnsea/Projet2A.AntHill/commits/806bd7dc6f03ab87a136ad6b5cb50cf98da0d80e'}]},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z'},
#  {'id': '19014689211',
#   'type': 'PushEvent',
#   'actor': {'id': 45207513,
#    'login': 'AzZotik',
#    'display_login': 'AzZotik',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AzZotik',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45207513?'},
#   'repo': {'id': 310841324,
#    'name': 'The-Triumvirate/Imperium-Universalis',
#    'url': 'https://api.github.com/repos/The-Triumvirate/Imperium-Universalis'},
#   'payload': {'push_id': 8453373974,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dev',
#    'head': '0ebf61f0847354da5d00dc784cce58e84008feed',
#    'before': 'a7f1c2e03f37eaf4b03b96db92329e26afad513b',
#    'commits': [{'sha': '0ebf61f0847354da5d00dc784cce58e84008feed',
#      'author': {'email': 'deasex25@ex.ua', 'name': 'Az'},
#      'message': 'fixed rigged elections',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/The-Triumvirate/Imperium-Universalis/commits/0ebf61f0847354da5d00dc784cce58e84008feed'}]},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z',
#   'org': {'id': 74100981,
#    'login': 'The-Triumvirate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/The-Triumvirate',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74100981?'}},
#  {'id': '19014689212',
#   'type': 'PullRequestReviewEvent',
#   'actor': {'id': 56551877,
#    'login': 'tpetillot',
#    'display_login': 'tpetillot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tpetillot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56551877?'},
#   'repo': {'id': 343372490,
#    'name': 'gatling/frontline-doc',
#    'url': 'https://api.github.com/repos/gatling/frontline-doc'},
#   'payload': {'action': 'created',
#    'review': {'id': 813639879,
#     'node_id': 'PRR_kwDOFHdyys4wfyjH',
#     'user': {'login': 'tpetillot',
#      'id': 56551877,
#      'node_id': 'MDQ6VXNlcjU2NTUxODc3',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/56551877?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/tpetillot',
#      'html_url': 'https://github.com/tpetillot',
#      'followers_url': 'https://api.github.com/users/tpetillot/followers',
#      'following_url': 'https://api.github.com/users/tpetillot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/tpetillot/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/tpetillot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/tpetillot/subscriptions',
#      'organizations_url': 'https://api.github.com/users/tpetillot/orgs',
#      'repos_url': 'https://api.github.com/users/tpetillot/repos',
#      'events_url': 'https://api.github.com/users/tpetillot/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/tpetillot/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'commit_id': 'ed9dbd7bc93911b03ee421dc4db545d772a56828',
#     'submitted_at': '2021-11-23T13:12:55Z',
#     'state': 'approved',
#     'html_url': 'https://github.com/gatling/frontline-doc/pull/36#pullrequestreview-813639879',
#     'pull_request_url': 'https://api.github.com/repos/gatling/frontline-doc/pulls/36',
#     'author_association': 'CONTRIBUTOR',
#     '_links': {'html': {'href': 'https://github.com/gatling/frontline-doc/pull/36#pullrequestreview-813639879'},
#      'pull_request': {'href': 'https://api.github.com/repos/gatling/frontline-doc/pulls/36'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/gatling/frontline-doc/pulls/36',
#     'id': 786858641,
#     'node_id': 'PR_kwDOFHdyys4u5oKR',
#     'html_url': 'https://github.com/gatling/frontline-doc/pull/36',
#     'diff_url': 'https://github.com/gatling/frontline-doc/pull/36.diff',
#     'patch_url': 'https://github.com/gatling/frontline-doc/pull/36.patch',
#     'issue_url': 'https://api.github.com/repos/gatling/frontline-doc/issues/36',
#     'number': 36,
#     'state': 'open',
#     'locked': False,
#     'title': 'chore: update user overview page, see MISC-284',
#     'user': {'login': 'guilgaly',
#      'id': 6560742,
#      'node_id': 'MDQ6VXNlcjY1NjA3NDI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/6560742?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/guilgaly',
#      'html_url': 'https://github.com/guilgaly',
#      'followers_url': 'https://api.github.com/users/guilgaly/followers',
#      'following_url': 'https://api.github.com/users/guilgaly/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/guilgaly/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/guilgaly/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/guilgaly/subscriptions',
#      'organizations_url': 'https://api.github.com/users/guilgaly/orgs',
#      'repos_url': 'https://api.github.com/users/guilgaly/repos',
#      'events_url': 'https://api.github.com/users/guilgaly/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/guilgaly/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Modifications:\r\n* small wording changes\r\n* download samples has been moved to simulations',
#     'created_at': '2021-11-23T11:00:19Z',
#     'updated_at': '2021-11-23T13:12:55Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'f0457bb6310ee6388255205f30483c7d8158269f',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/gatling/frontline-doc/pulls/36/commits',
#     'review_comments_url': 'https://api.github.com/repos/gatling/frontline-doc/pulls/36/comments',
#     'review_comment_url': 'https://api.github.com/repos/gatling/frontline-doc/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/gatling/frontline-doc/issues/36/comments',
#     'statuses_url': 'https://api.github.com/repos/gatling/frontline-doc/statuses/ed9dbd7bc93911b03ee421dc4db545d772a56828',
#     'head': {'label': 'gatling:misc-284-user-overview',
#      'ref': 'misc-284-user-overview',
#      'sha': 'ed9dbd7bc93911b03ee421dc4db545d772a56828',
#      'user': {'login': 'gatling',
#       'id': 3863781,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM4NjM3ODE=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/3863781?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/gatling',
#       'html_url': 'https://github.com/gatling',
#       'followers_url': 'https://api.github.com/users/gatling/followers',
#       'following_url': 'https://api.github.com/users/gatling/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/gatling/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/gatling/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/gatling/subscriptions',
#       'organizations_url': 'https://api.github.com/users/gatling/orgs',
#       'repos_url': 'https://api.github.com/users/gatling/repos',
#       'events_url': 'https://api.github.com/users/gatling/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/gatling/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 343372490,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNDMzNzI0OTA=',
#       'name': 'frontline-doc',
#       'full_name': 'gatling/frontline-doc',
#       'private': False,
#       'owner': {'login': 'gatling',
#        'id': 3863781,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM4NjM3ODE=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/3863781?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/gatling',
#        'html_url': 'https://github.com/gatling',
#        'followers_url': 'https://api.github.com/users/gatling/followers',
#        'following_url': 'https://api.github.com/users/gatling/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/gatling/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/gatling/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/gatling/subscriptions',
#        'organizations_url': 'https://api.github.com/users/gatling/orgs',
#        'repos_url': 'https://api.github.com/users/gatling/repos',
#        'events_url': 'https://api.github.com/users/gatling/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/gatling/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/gatling/frontline-doc',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/gatling/frontline-doc',
#       'forks_url': 'https://api.github.com/repos/gatling/frontline-doc/forks',
#       'keys_url': 'https://api.github.com/repos/gatling/frontline-doc/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/gatling/frontline-doc/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/gatling/frontline-doc/teams',
#       'hooks_url': 'https://api.github.com/repos/gatling/frontline-doc/hooks',
#       'issue_events_url': 'https://api.github.com/repos/gatling/frontline-doc/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/gatling/frontline-doc/events',
#       'assignees_url': 'https://api.github.com/repos/gatling/frontline-doc/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/gatling/frontline-doc/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/gatling/frontline-doc/tags',
#       'blobs_url': 'https://api.github.com/repos/gatling/frontline-doc/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/gatling/frontline-doc/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/gatling/frontline-doc/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/gatling/frontline-doc/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/gatling/frontline-doc/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/gatling/frontline-doc/languages',
#       'stargazers_url': 'https://api.github.com/repos/gatling/frontline-doc/stargazers',
#       'contributors_url': 'https://api.github.com/repos/gatling/frontline-doc/contributors',
#       'subscribers_url': 'https://api.github.com/repos/gatling/frontline-doc/subscribers',
#       'subscription_url': 'https://api.github.com/repos/gatling/frontline-doc/subscription',
#       'commits_url': 'https://api.github.com/repos/gatling/frontline-doc/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/gatling/frontline-doc/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/gatling/frontline-doc/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/gatling/frontline-doc/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/gatling/frontline-doc/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/gatling/frontline-doc/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/gatling/frontline-doc/merges',
#       'archive_url': 'https://api.github.com/repos/gatling/frontline-doc/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/gatling/frontline-doc/downloads',
#       'issues_url': 'https://api.github.com/repos/gatling/frontline-doc/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/gatling/frontline-doc/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/gatling/frontline-doc/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/gatling/frontline-doc/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/gatling/frontline-doc/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/gatling/frontline-doc/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/gatling/frontline-doc/deployments',
#       'created_at': '2021-03-01T10:16:16Z',
#       'updated_at': '2021-11-23T10:40:01Z',
#       'pushed_at': '2021-11-23T11:38:57Z',
#       'git_url': 'git://github.com/gatling/frontline-doc.git',
#       'ssh_url': 'git@github.com:gatling/frontline-doc.git',
#       'clone_url': 'https://github.com/gatling/frontline-doc.git',
#       'svn_url': 'https://github.com/gatling/frontline-doc',
#       'homepage': None,
#       'size': 14134,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': False,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 5,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 5,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'gatling:main',
#      'ref': 'main',
#      'sha': 'fea60f65a55f866b4d495374b007989d5faa0eae',
#      'user': {'login': 'gatling',
#       'id': 3863781,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM4NjM3ODE=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/3863781?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/gatling',
#       'html_url': 'https://github.com/gatling',
#       'followers_url': 'https://api.github.com/users/gatling/followers',
#       'following_url': 'https://api.github.com/users/gatling/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/gatling/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/gatling/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/gatling/subscriptions',
#       'organizations_url': 'https://api.github.com/users/gatling/orgs',
#       'repos_url': 'https://api.github.com/users/gatling/repos',
#       'events_url': 'https://api.github.com/users/gatling/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/gatling/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 343372490,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNDMzNzI0OTA=',
#       'name': 'frontline-doc',
#       'full_name': 'gatling/frontline-doc',
#       'private': False,
#       'owner': {'login': 'gatling',
#        'id': 3863781,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM4NjM3ODE=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/3863781?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/gatling',
#        'html_url': 'https://github.com/gatling',
#        'followers_url': 'https://api.github.com/users/gatling/followers',
#        'following_url': 'https://api.github.com/users/gatling/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/gatling/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/gatling/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/gatling/subscriptions',
#        'organizations_url': 'https://api.github.com/users/gatling/orgs',
#        'repos_url': 'https://api.github.com/users/gatling/repos',
#        'events_url': 'https://api.github.com/users/gatling/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/gatling/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/gatling/frontline-doc',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/gatling/frontline-doc',
#       'forks_url': 'https://api.github.com/repos/gatling/frontline-doc/forks',
#       'keys_url': 'https://api.github.com/repos/gatling/frontline-doc/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/gatling/frontline-doc/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/gatling/frontline-doc/teams',
#       'hooks_url': 'https://api.github.com/repos/gatling/frontline-doc/hooks',
#       'issue_events_url': 'https://api.github.com/repos/gatling/frontline-doc/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/gatling/frontline-doc/events',
#       'assignees_url': 'https://api.github.com/repos/gatling/frontline-doc/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/gatling/frontline-doc/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/gatling/frontline-doc/tags',
#       'blobs_url': 'https://api.github.com/repos/gatling/frontline-doc/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/gatling/frontline-doc/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/gatling/frontline-doc/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/gatling/frontline-doc/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/gatling/frontline-doc/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/gatling/frontline-doc/languages',
#       'stargazers_url': 'https://api.github.com/repos/gatling/frontline-doc/stargazers',
#       'contributors_url': 'https://api.github.com/repos/gatling/frontline-doc/contributors',
#       'subscribers_url': 'https://api.github.com/repos/gatling/frontline-doc/subscribers',
#       'subscription_url': 'https://api.github.com/repos/gatling/frontline-doc/subscription',
#       'commits_url': 'https://api.github.com/repos/gatling/frontline-doc/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/gatling/frontline-doc/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/gatling/frontline-doc/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/gatling/frontline-doc/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/gatling/frontline-doc/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/gatling/frontline-doc/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/gatling/frontline-doc/merges',
#       'archive_url': 'https://api.github.com/repos/gatling/frontline-doc/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/gatling/frontline-doc/downloads',
#       'issues_url': 'https://api.github.com/repos/gatling/frontline-doc/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/gatling/frontline-doc/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/gatling/frontline-doc/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/gatling/frontline-doc/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/gatling/frontline-doc/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/gatling/frontline-doc/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/gatling/frontline-doc/deployments',
#       'created_at': '2021-03-01T10:16:16Z',
#       'updated_at': '2021-11-23T10:40:01Z',
#       'pushed_at': '2021-11-23T11:38:57Z',
#       'git_url': 'git://github.com/gatling/frontline-doc.git',
#       'ssh_url': 'git@github.com:gatling/frontline-doc.git',
#       'clone_url': 'https://github.com/gatling/frontline-doc.git',
#       'svn_url': 'https://github.com/gatling/frontline-doc',
#       'homepage': None,
#       'size': 14134,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': False,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 5,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 5,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/gatling/frontline-doc/pulls/36'},
#      'html': {'href': 'https://github.com/gatling/frontline-doc/pull/36'},
#      'issue': {'href': 'https://api.github.com/repos/gatling/frontline-doc/issues/36'},
#      'comments': {'href': 'https://api.github.com/repos/gatling/frontline-doc/issues/36/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/gatling/frontline-doc/pulls/36/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/gatling/frontline-doc/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/gatling/frontline-doc/pulls/36/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/gatling/frontline-doc/statuses/ed9dbd7bc93911b03ee421dc4db545d772a56828'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z',
#   'org': {'id': 3863781,
#    'login': 'gatling',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/gatling',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3863781?'}},
#  {'id': '19014689218',
#   'type': 'PushEvent',
#   'actor': {'id': 77077433,
#    'login': 'gitbykoga',
#    'display_login': 'gitbykoga',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gitbykoga',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77077433?'},
#   'repo': {'id': 431098455,
#    'name': 'gitbykoga/mirna',
#    'url': 'https://api.github.com/repos/gitbykoga/mirna'},
#   'payload': {'push_id': 8453374034,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '7a126c232e594f485e3148c958b330da4e575e8c',
#    'before': '2652cec47b2de0e720956e9a20a0181407a0002b',
#    'commits': [{'sha': '7a126c232e594f485e3148c958b330da4e575e8c',
#      'author': {'email': 'mailbykoga@gmail.com', 'name': 'André Koga'},
#      'message': 'Update CNAME',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/gitbykoga/mirna/commits/7a126c232e594f485e3148c958b330da4e575e8c'}]},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z'},
#  {'id': '19014689196',
#   'type': 'PushEvent',
#   'actor': {'id': 936617,
#    'login': 'mes51',
#    'display_login': 'mes51',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mes51',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/936617?'},
#   'repo': {'id': 396211059,
#    'name': 'mes51/voicevox',
#    'url': 'https://api.github.com/repos/mes51/voicevox'},
#   'payload': {'push_id': 8453373969,
#    'size': 3,
#    'distinct_size': 3,
#    'ref': 'refs/heads/install-gtm',
#    'head': '32aef48dda900a893335c6d6d70395b670a0e896',
#    'before': '4dab33b2f7c26d06996aa369f4b3b5f26ac5f852',
#    'commits': [{'sha': '99f5db360fec0eaf81fb506c140396c47ede4a00',
#      'author': {'email': 'mes.goruba@gmail.com', 'name': 'mes51'},
#      'message': 'remove telemetry setting view',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mes51/voicevox/commits/99f5db360fec0eaf81fb506c140396c47ede4a00'},
#     {'sha': '63ee682c6453e7fdc339a87ea9a8d509dfa79130',
#      'author': {'email': 'mes.goruba@gmail.com', 'name': 'mes51'},
#      'message': 'fixed vue-gtm version',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mes51/voicevox/commits/63ee682c6453e7fdc339a87ea9a8d509dfa79130'},
#     {'sha': '32aef48dda900a893335c6d6d70395b670a0e896',
#      'author': {'email': 'mes.goruba@gmail.com', 'name': 'mes51'},
#      'message': 'change accept retrieve telemetry status type',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mes51/voicevox/commits/32aef48dda900a893335c6d6d70395b670a0e896'}]},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z'},
#  {'id': '19014689213',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 355296176,
#    'name': 'engramar/engramar',
#    'url': 'https://api.github.com/repos/engramar/engramar'},
#   'payload': {'push_id': 8453374011,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'bc65b68df6c7da9892cc3493e89a184de6e3702e',
#    'before': '03791a488870426284bbeb1400b0bff5de940f50',
#    'commits': [{'sha': 'bc65b68df6c7da9892cc3493e89a184de6e3702e',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Update github-metrics.svg - [Skip GitHub Action]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/engramar/engramar/commits/bc65b68df6c7da9892cc3493e89a184de6e3702e'}]},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z'},
#  {'id': '19014689172',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 431065911,
#    'name': 'xorob0/docs',
#    'url': 'https://api.github.com/repos/xorob0/docs'},
#   'payload': {'push_id': 8453374000,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '2c9947c6cbc3e7cc28ecc3bf343454b58b9b8205',
#    'before': 'e9253ab22bb296e73fa8402a2f00b463e13affe1',
#    'commits': [{'sha': '2c9947c6cbc3e7cc28ecc3bf343454b58b9b8205',
#      'author': {'email': '', 'name': ''},
#      'message': 'Deployed e7ac19d with MkDocs version: 1.2.3',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/xorob0/docs/commits/2c9947c6cbc3e7cc28ecc3bf343454b58b9b8205'}]},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z'},
#  {'id': '19014689165',
#   'type': 'PushEvent',
#   'actor': {'id': 40890096,
#    'login': 'hantyou',
#    'display_login': 'hantyou',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hantyou',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40890096?'},
#   'repo': {'id': 431103598,
#    'name': 'hantyou/hantyou.github.io',
#    'url': 'https://api.github.com/repos/hantyou/hantyou.github.io'},
#   'payload': {'push_id': 8453373961,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '875fe9bb82cc798f247dc9514be3570d5bd5ddc3',
#    'before': '2b49eabceaf676b28bf68111d8925d888d251b89',
#    'commits': [{'sha': '875fe9bb82cc798f247dc9514be3570d5bd5ddc3',
#      'author': {'email': 'daniel.zhai@yahoo.com', 'name': 'Peiyuan Zhai'},
#      'message': 'Set theme jekyll-theme-cayman',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hantyou/hantyou.github.io/commits/875fe9bb82cc798f247dc9514be3570d5bd5ddc3'}]},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z'},
#  {'id': '19014689154',
#   'type': 'PushEvent',
#   'actor': {'id': 3012076,
#    'login': 'fzipi',
#    'display_login': 'fzipi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fzipi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3012076?'},
#   'repo': {'id': 109747128,
#    'name': 'fzipi/modsecurity-docker',
#    'url': 'https://api.github.com/repos/fzipi/modsecurity-docker'},
#   'payload': {'push_id': 8453373979,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/fix-cve-2021-42717',
#    'head': 'da620e5c2a1629d66af481b99c171f991cdaf48a',
#    'before': '9b22a3944989a2c2e08d0b51a6e82d98ee1c26f3',
#    'commits': [{'sha': 'da620e5c2a1629d66af481b99c171f991cdaf48a',
#      'author': {'email': 'felipe.zipitria@owasp.org',
#       'name': 'Felipe Zipitria'},
#      'message': 'fix(cve): update modsecurity version\n\nSigned-off-by: Felipe Zipitria <felipe.zipitria@owasp.org>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fzipi/modsecurity-docker/commits/da620e5c2a1629d66af481b99c171f991cdaf48a'}]},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z'},
#  {'id': '19014689180',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 65553080,
#    'login': 'codecov-commenter',
#    'display_login': 'codecov-commenter',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/codecov-commenter',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65553080?'},
#   'repo': {'id': 392295254,
#    'name': 'FUGA0618/serurepo',
#    'url': 'https://api.github.com/repos/FUGA0618/serurepo'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/FUGA0618/serurepo/issues/168',
#     'repository_url': 'https://api.github.com/repos/FUGA0618/serurepo',
#     'labels_url': 'https://api.github.com/repos/FUGA0618/serurepo/issues/168/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/FUGA0618/serurepo/issues/168/comments',
#     'events_url': 'https://api.github.com/repos/FUGA0618/serurepo/issues/168/events',
#     'html_url': 'https://github.com/FUGA0618/serurepo/pull/168',
#     'id': 1061224699,
#     'node_id': 'PR_kwDOF2HzVs4u543D',
#     'number': 168,
#     'title': 'AmazonCrawlerの金額取得方法を変更',
#     'user': {'login': 'FUGA0618',
#      'id': 58870882,
#      'node_id': 'MDQ6VXNlcjU4ODcwODgy',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/58870882?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/FUGA0618',
#      'html_url': 'https://github.com/FUGA0618',
#      'followers_url': 'https://api.github.com/users/FUGA0618/followers',
#      'following_url': 'https://api.github.com/users/FUGA0618/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/FUGA0618/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/FUGA0618/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/FUGA0618/subscriptions',
#      'organizations_url': 'https://api.github.com/users/FUGA0618/orgs',
#      'repos_url': 'https://api.github.com/users/FUGA0618/repos',
#      'events_url': 'https://api.github.com/users/FUGA0618/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/FUGA0618/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2021-11-23T12:28:56Z',
#     'updated_at': '2021-11-23T13:12:56Z',
#     'closed_at': None,
#     'author_association': 'OWNER',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/FUGA0618/serurepo/pulls/168',
#      'html_url': 'https://github.com/FUGA0618/serurepo/pull/168',
#      'diff_url': 'https://github.com/FUGA0618/serurepo/pull/168.diff',
#      'patch_url': 'https://github.com/FUGA0618/serurepo/pull/168.patch',
#      'merged_at': None},
#     'body': 'ref: #162 \r\n\r\naudible版がある書籍だと、`ver_list_dom[1]`はaudible版の金額になってしまう。\r\n`ver_list_dom[-1]`として、audible版があってもなくても紙書籍の金額を取得できるように修正した。',
#     'reactions': {'url': 'https://api.github.com/repos/FUGA0618/serurepo/issues/168/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/FUGA0618/serurepo/issues/168/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/FUGA0618/serurepo/issues/comments/976513129',
#     'html_url': 'https://github.com/FUGA0618/serurepo/pull/168#issuecomment-976513129',
#     'issue_url': 'https://api.github.com/repos/FUGA0618/serurepo/issues/168',
#     'id': 976513129,
#     'node_id': 'IC_kwDOF2HzVs46NGhp',
#     'user': {'login': 'codecov-commenter',
#      'id': 65553080,
#      'node_id': 'MDQ6VXNlcjY1NTUzMDgw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/65553080?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/codecov-commenter',
#      'html_url': 'https://github.com/codecov-commenter',
#      'followers_url': 'https://api.github.com/users/codecov-commenter/followers',
#      'following_url': 'https://api.github.com/users/codecov-commenter/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/codecov-commenter/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/codecov-commenter/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/codecov-commenter/subscriptions',
#      'organizations_url': 'https://api.github.com/users/codecov-commenter/orgs',
#      'repos_url': 'https://api.github.com/users/codecov-commenter/repos',
#      'events_url': 'https://api.github.com/users/codecov-commenter/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/codecov-commenter/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2021-11-23T13:12:55Z',
#     'updated_at': '2021-11-23T13:12:55Z',
#     'author_association': 'NONE',
#     'body': '# [Codecov](https://codecov.io/gh/FUGA0618/serurepo/pull/168?src=pr&el=h1&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=Fu-ga) Report\n> Merging [#168](https://codecov.io/gh/FUGA0618/serurepo/pull/168?src=pr&el=desc&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=Fu-ga) (f77bced) into [main](https://codecov.io/gh/FUGA0618/serurepo/commit/ae499d826828ce3048207ffa166c984f8697efde?el=desc&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=Fu-ga) (ae499d8) will **decrease** coverage by `1.46%`.\n> The diff coverage is `100.00%`.\n\n[![Impacted file tree graph](https://codecov.io/gh/FUGA0618/serurepo/pull/168/graphs/tree.svg?width=650&height=150&src=pr&token=XPH2NIQQGP&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=Fu-ga)](https://codecov.io/gh/FUGA0618/serurepo/pull/168?src=pr&el=tree&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=Fu-ga)\n\n```diff\n@@            Coverage Diff             @@\n##             main     #168      +/-   ##\n==========================================\n- Coverage   90.90%   89.44%   -1.47%     \n==========================================\n  Files          29       29              \n  Lines         341      341              \n==========================================\n- Hits          310      305       -5     \n- Misses         31       36       +5     \n```\n\n\n| [Impacted Files](https://codecov.io/gh/FUGA0618/serurepo/pull/168?src=pr&el=tree&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=Fu-ga) | Coverage Δ | |\n|---|---|---|\n| [lib/crawler/amazon\\_crawler.rb](https://codecov.io/gh/FUGA0618/serurepo/pull/168/diff?src=pr&el=tree&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=Fu-ga#diff-bGliL2NyYXdsZXIvYW1hem9uX2NyYXdsZXIucmI=) | `81.48% <100.00%> (-18.52%)` | :arrow_down: |\n\n------\n\n[Continue to review full report at Codecov](https://codecov.io/gh/FUGA0618/serurepo/pull/168?src=pr&el=continue&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=Fu-ga).\n> **Legend** - [Click here to learn more](https://docs.codecov.io/docs/codecov-delta?utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=Fu-ga)\n> `Δ = absolute <relative> (impact)`, `ø = not affected`, `? = missing data`\n> Powered by [Codecov](https://codecov.io/gh/FUGA0618/serurepo/pull/168?src=pr&el=footer&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=Fu-ga). Last update [ae499d8...f77bced](https://codecov.io/gh/FUGA0618/serurepo/pull/168?src=pr&el=lastupdated&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=Fu-ga). Read the [comment docs](https://docs.codecov.io/docs/pull-request-comments?utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=Fu-ga).\n',
#     'reactions': {'url': 'https://api.github.com/repos/FUGA0618/serurepo/issues/comments/976513129/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z'},
#  {'id': '19014689203',
#   'type': 'IssuesEvent',
#   'actor': {'id': 2273250,
#    'login': 'nosalan',
#    'display_login': 'nosalan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nosalan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2273250?'},
#   'repo': {'id': 131145697,
#    'name': 'Azure-Samples/cognitive-services-speech-sdk',
#    'url': 'https://api.github.com/repos/Azure-Samples/cognitive-services-speech-sdk'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/Azure-Samples/cognitive-services-speech-sdk/issues/1329',
#     'repository_url': 'https://api.github.com/repos/Azure-Samples/cognitive-services-speech-sdk',
#     'labels_url': 'https://api.github.com/repos/Azure-Samples/cognitive-services-speech-sdk/issues/1329/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/Azure-Samples/cognitive-services-speech-sdk/issues/1329/comments',
#     'events_url': 'https://api.github.com/repos/Azure-Samples/cognitive-services-speech-sdk/issues/1329/events',
#     'html_url': 'https://github.com/Azure-Samples/cognitive-services-speech-sdk/issues/1329',
#     'id': 1061273660,
#     'node_id': 'I_kwDOB9Ef4c4_QcA8',
#     'number': 1329,
#     'title': 'Confidence possible values ',
#     'user': {'login': 'nosalan',
#      'id': 2273250,
#      'node_id': 'MDQ6VXNlcjIyNzMyNTA=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/2273250?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/nosalan',
#      'html_url': 'https://github.com/nosalan',
#      'followers_url': 'https://api.github.com/users/nosalan/followers',
#      'following_url': 'https://api.github.com/users/nosalan/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/nosalan/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/nosalan/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/nosalan/subscriptions',
#      'organizations_url': 'https://api.github.com/users/nosalan/orgs',
#      'repos_url': 'https://api.github.com/users/nosalan/repos',
#      'events_url': 'https://api.github.com/users/nosalan/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/nosalan/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2021-11-23T13:12:55Z',
#     'updated_at': '2021-11-23T13:12:55Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
# ...
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['alps',
#        'api-specification',
#        'hypermedia-api',
#        'state-diagram'],
#       'visibility': 'public',
#       'forks': 5,
#       'open_issues': 3,
#       'watchers': 18,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/alps-asd/app-state-diagram/pulls/127'},
#      'html': {'href': 'https://github.com/alps-asd/app-state-diagram/pull/127'},
#      'issue': {'href': 'https://api.github.com/repos/alps-asd/app-state-diagram/issues/127'},
#      'comments': {'href': 'https://api.github.com/repos/alps-asd/app-state-diagram/issues/127/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/alps-asd/app-state-diagram/pulls/127/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/alps-asd/app-state-diagram/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/alps-asd/app-state-diagram/pulls/127/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/alps-asd/app-state-diagram/statuses/f93aba9ed20e35a0e448ff6aa45fe3153e5f9ae1'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 2,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z',
#   'org': {'id': 94894708,
#    'login': 'alps-asd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/alps-asd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94894708?'}},
#  {'id': '19014689120',
#   'type': 'PushEvent',
#   'actor': {'id': 24569428,
#    'login': 'vlukashenko',
#    'display_login': 'vlukashenko',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vlukashenko',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24569428?'},
#   'repo': {'id': 90251099,
#    'name': 'lhcb/starterkit-lessons',
#    'url': 'https://api.github.com/repos/lhcb/starterkit-lessons'},
#   'payload': {'push_id': 8453373940,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2e3f929a007da98f3825418fc07a137a2ad86d0e',
#    'before': '4a7e01e67de7d27c214476383678a6d84d5a3a30',
#    'commits': [{'sha': '2e3f929a007da98f3825418fc07a137a2ad86d0e',
#      'author': {'email': 'laurent.dufour@cern.ch', 'name': 'Laurent Dufour'},
#      'message': 'Update analysisflow.md (#279)\n\nThe actual reproduction is not a requirement for analyses.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lhcb/starterkit-lessons/commits/2e3f929a007da98f3825418fc07a137a2ad86d0e'}]},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z',
#   'org': {'id': 924952,
#    'login': 'lhcb',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/lhcb',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/924952?'}},
#  {'id': '19014689118',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 381370648,
#    'name': 'allwaysLove/AutoApiSR',
#    'url': 'https://api.github.com/repos/allwaysLove/AutoApiSR'},
#   'payload': {'push_id': 8453373929,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6478a83e7a7853f38a60782fe948355463812d21',
#    'before': 'b48cc1121ed5c34370c4f497250989648e6b13d1',
#    'commits': [{'sha': '6478a83e7a7853f38a60782fe948355463812d21',
#      'author': {'email': 'AutoupdateRobot@email.com',
#       'name': 'AutoupdateRobot'},
#      'message': 'update new refresh_token',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/allwaysLove/AutoApiSR/commits/6478a83e7a7853f38a60782fe948355463812d21'}]},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z'},
#  {'id': '19014689136',
#   'type': 'PushEvent',
#   'actor': {'id': 91777845,
#    'login': 'ganeshabhi1',
#    'display_login': 'ganeshabhi1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ganeshabhi1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/91777845?'},
#   'repo': {'id': 428962828,
#    'name': 'ganeshabhi1/ETG',
#    'url': 'https://api.github.com/repos/ganeshabhi1/ETG'},
#   'payload': {'push_id': 8453373982,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '346376201d177babaf81481f7a9ab19883001733',
#    'before': '2c0e1c4b7edc6c487fe2cfb3eaf15b934e6663dd',
#    'commits': [{'sha': '346376201d177babaf81481f7a9ab19883001733',
#      'author': {'email': '91777845+ganeshabhi1@users.noreply.github.com',
#       'name': 'ganeshabhi1'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ganeshabhi1/ETG/commits/346376201d177babaf81481f7a9ab19883001733'}]},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z'},
#  {'id': '19014689112',
#   'type': 'DeleteEvent',
#   'actor': {'id': 44968488,
#    'login': 'laurent2207',
#    'display_login': 'laurent2207',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/laurent2207',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44968488?'},
#   'repo': {'id': 238230090,
#    'name': 'MaastrichtUniversity/mirthconnect-docker',
#    'url': 'https://api.github.com/repos/MaastrichtUniversity/mirthconnect-docker'},
#   'payload': {'ref': 'DHDO-232', 'ref_type': 'branch', 'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z',
#   'org': {'id': 12815212,
#    'login': 'MaastrichtUniversity',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/MaastrichtUniversity',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12815212?'}},
#  {'id': '19014689129',
#   'type': 'CreateEvent',
#   'actor': {'id': 85168021,
#    'login': 'shyam-j',
#    'display_login': 'shyam-j',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shyam-j',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/85168021?'},
#   'repo': {'id': 372839829,
#    'name': 'TexasInstruments/edgeai-gst-plugins',
#    'url': 'https://api.github.com/repos/TexasInstruments/edgeai-gst-plugins'},
#   'payload': {'ref': 'fix/pkgconfig-imaging-sdk-update',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': "Repository to host GStreamer plugins for TI's EdgeAI class of devices",
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z',
#   'org': {'id': 24322022,
#    'login': 'TexasInstruments',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/TexasInstruments',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24322022?'}},
#  {'id': '19014689108',
#   'type': 'PushEvent',
#   'actor': {'id': 90760767,
#    'login': 'waldofx',
#    'display_login': 'waldofx',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/waldofx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/90760767?'},
#   'repo': {'id': 430126883,
#    'name': 'waldofx/Save-the-Seas',
#    'url': 'https://api.github.com/repos/waldofx/Save-the-Seas'},
#   'payload': {'push_id': 8453373953,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/featureVolunteer',
#    'head': 'b0e158bd80705e10950f819d98e1f6ccfcd76000',
#    'before': '986b3bcae7856767584bacfffd478705b825cf74',
#    'commits': [{'sha': 'b0e158bd80705e10950f819d98e1f6ccfcd76000',
#      'author': {'email': '90760767+waldofx@users.noreply.github.com',
#       'name': 'waldofx'},
#      'message': 'Basic query in volunteer page\n\nFirst up, sort descending by participants. Managed to show up, but not styled/formatted in anyway.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/waldofx/Save-the-Seas/commits/b0e158bd80705e10950f819d98e1f6ccfcd76000'}]},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z'},
#  {'id': '19014689101',
#   'type': 'CreateEvent',
#   'actor': {'id': 71294409,
#    'login': 'nat-1501',
#    'display_login': 'nat-1501',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nat-1501',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71294409?'},
#   'repo': {'id': 431106007,
#    'name': 'nat-1501/siteNataliSoares',
#    'url': 'https://api.github.com/repos/nat-1501/siteNataliSoares'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'Portifólio  ',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z'},
#  {'id': '19014689099',
#   'type': 'PushEvent',
#   'actor': {'id': 14878713,
#    'login': 'tiltom',
#    'display_login': 'tiltom',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tiltom',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14878713?'},
#   'repo': {'id': 286428067,
#    'name': 'DistributedCollective/Sovryn-frontend',
#    'url': 'https://api.github.com/repos/DistributedCollective/Sovryn-frontend'},
#   'payload': {'push_id': 8453373923,
#    'size': 6,
#    'distinct_size': 1,
#    'ref': 'refs/heads/feat/434-perpetuals',
#    'head': 'b4f272ed1603895b5a57bcbd74edebdccdd247b1',
#    'before': 'a901b8ec4d0e83f8daf3cfda10e2aa5eeaaf5f16',
#    'commits': [{'sha': '8dbfe6b1ac5dd101bf3d29983aabbf30a0e16ab2',
#      'author': {'email': 'tilnak.tomas@gmail.com', 'name': 'tiltom'},
#      'message': 'Implement account balance',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/DistributedCollective/Sovryn-frontend/commits/8dbfe6b1ac5dd101bf3d29983aabbf30a0e16ab2'},
#     {'sha': '708b7f91e7aa8ad6751711036ebf39144f3da20c',
#      'author': {'email': 'tilnak.tomas@gmail.com', 'name': 'tiltom'},
#      'message': 'Implement Contract details',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/DistributedCollective/Sovryn-frontend/commits/708b7f91e7aa8ad6751711036ebf39144f3da20c'},
#     {'sha': '925037525beecbf9c990b55a639d887022176017',
#      'author': {'email': 'tilnak.tomas@gmail.com', 'name': 'tiltom'},
#      'message': 'Review adjustments',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/DistributedCollective/Sovryn-frontend/commits/925037525beecbf9c990b55a639d887022176017'},
#     {'sha': 'd5a41e22cb83730ff3f511f335bf29dc7db33496',
#      'author': {'email': 'tilnak.tomas@gmail.com', 'name': 'tiltom'},
#      'message': 'Add Open Interest and 24h volume',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/DistributedCollective/Sovryn-frontend/commits/d5a41e22cb83730ff3f511f335bf29dc7db33496'},
#     {'sha': 'f508be091d3a1a7341362efe86e15e570409a545',
#      'author': {'email': 'tilnak.tomas@gmail.com', 'name': 'tiltom'},
#      'message': 'Minor adjustments',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/DistributedCollective/Sovryn-frontend/commits/f508be091d3a1a7341362efe86e15e570409a545'},
#     {'sha': 'b4f272ed1603895b5a57bcbd74edebdccdd247b1',
#      'author': {'email': 'tilnak.tomas@gmail.com', 'name': 'tiltom'},
#      'message': 'Merge pull request #1892 from DistributedCollective/feat/648-contract-details-and-available-balance-values\n\nGet Contract details and Available balance real values instead of placeholders',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/DistributedCollective/Sovryn-frontend/commits/b4f272ed1603895b5a57bcbd74edebdccdd247b1'}]},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z',
#   'org': {'id': 63802000,
#    'login': 'DistributedCollective',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DistributedCollective',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63802000?'}},
#  {'id': '19014689127',
#   'type': 'PushEvent',
#   'actor': {'id': 36952722,
#    'login': 'araihC',
#    'display_login': 'araihC',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/araihC',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36952722?'},
#   'repo': {'id': 255878159,
#    'name': 'APE-group/wavescalephant',
#    'url': 'https://api.github.com/repos/APE-group/wavescalephant'},
#   'payload': {'push_id': 8453373972,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd8167ac9c968b9902f03a73d3634ea0d9c0e1f92',
#    'before': '7ff553cf2eda19fd63477ea26959f031da498793',
#    'commits': [{'sha': 'd8167ac9c968b9902f03a73d3634ea0d9c0e1f92',
#      'author': {'email': 'chdeluca18@gmail.com', 'name': 'Chiara De Luca'},
#      'message': 'Allign to INM6',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/APE-group/wavescalephant/commits/d8167ac9c968b9902f03a73d3634ea0d9c0e1f92'}]},
#   'public': True,
#   'created_at': '2021-11-23T13:12:56Z',
#   'org': {'id': 45791403,
#    'login': 'APE-group',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/APE-group',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45791403?'}},
#  {'id': '19014689107',
#   'type': 'CommitCommentEvent',
#   'actor': {'id': 35613825,
#    'login': 'vercel[bot]',
#    'display_login': 'vercel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vercel[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35613825?'},
#   'repo': {'id': 431104181,
#    'name': 'ugurhan-b/AsciiEffect_webpack',
#    'url': 'https://api.github.com/repos/ugurhan-b/AsciiEffect_webpack'},
#   'payload': {'comment': {'url': 'https://api.github.com/repos/ugurhan-b/AsciiEffect_webpack/comments/60743379',
#     'html_url': 'https://github.com/ugurhan-b/AsciiEffect_webpack/commit/d0497113d783a77fdd507ac3ac9f5556f58c9d36#commitcomment-60743379',
#     'id': 60743379,
#     'node_id': 'CC_kwDOGbIgtc4Dnt7T',
#     'user': {'login': 'vercel[bot]',
#      'id': 35613825,
#      'node_id': 'MDM6Qm90MzU2MTM4MjU=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/8329?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/vercel%5Bbot%5D',
#      'html_url': 'https://github.com/apps/vercel',
#      'followers_url': 'https://api.github.com/users/vercel%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/vercel%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/vercel%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/vercel%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/vercel%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/vercel%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/vercel%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/vercel%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/vercel%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'position': None,
#     'line': None,
#     'path': None,
#     'commit_id': 'd0497113d783a77fdd507ac3ac9f5556f58c9d36',
#     'created_at': '2021-11-23T13:12:55Z',
#     'updated_at': '2021-11-23T13:12:55Z',
#     'author_association': 'NONE',
#     'body': 'Successfully deployed to the following URLs:\n\n* [ascii-effect-webpack.vercel.app](https://ascii-effect-webpack.vercel.app)  \n* [ascii-effect-webpack-ugurhanbuyukozcu-gmailcom.vercel.app](https://ascii-effect-webpack-ugurhanbuyukozcu-gmailcom.vercel.app)  \n* [ascii-effect-webpack-git-main-ugurhanbuyukozcu-gmailcom.vercel.app](https://ascii-effect-webpack-git-main-ugurhanbuyukozcu-gmailcom.vercel.app)',
#     'reactions': {'url': 'https://api.github.com/repos/ugurhan-b/AsciiEffect_webpack/comments/60743379/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0}}},
#   'public': True,
#   'created_at': '2021-11-23T13:12:55Z'}]

# %%
from IPython.display import JSON
JSON(response.json())

# %%
len(github_response)
# Out:
# 30

# %%
#login
github_response[3]["actor"]["login"]
# Out:
# 'liya2017'

# %% [markdown]
# ### Exercise:
#
# Extract the "login", the repo name and the event type for each event.

# %%
github_response[0]["actor"]["login"]
# Out:
# 'botcopado'

# %%
for resp in github_response:
    login = resp["actor"]["login"]
    repo_name = resp["repo"]["name"]
    event_type = resp["type"]
    print(login, ' - ', repo_name, ' - ', event_type,'\n')
# Out:
# akiyosi  -  renerocksai/telekasten.nvim  -  WatchEvent
#
# rjpagano  -  rjpagano/covid_19_counties  -  PushEvent
#
# CorentinNrd  -  CorentinNrd/Portfolio-Corentin  -  CreateEvent
#
# dmitryshelomanov  -  jaredpalmer/razzle  -  IssueCommentEvent
#
# Paul-Recamier  -  TarekBEnsea/Projet2A.AntHill  -  PushEvent
#
# AzZotik  -  The-Triumvirate/Imperium-Universalis  -  PushEvent
#
# tpetillot  -  gatling/frontline-doc  -  PullRequestReviewEvent
#
# gitbykoga  -  gitbykoga/mirna  -  PushEvent
#
# mes51  -  mes51/voicevox  -  PushEvent
#
# github-actions[bot]  -  engramar/engramar  -  PushEvent
#
# github-actions[bot]  -  xorob0/docs  -  PushEvent
#
# hantyou  -  hantyou/hantyou.github.io  -  PushEvent
#
# fzipi  -  fzipi/modsecurity-docker  -  PushEvent
#
# codecov-commenter  -  FUGA0618/serurepo  -  IssueCommentEvent
#
# nosalan  -  Azure-Samples/cognitive-services-speech-sdk  -  IssuesEvent
#
# lucastomkiel  -  neogrid-brazil/dojo-tests-frontend  -  PushEvent
#
# Zurina  -  Dive-Into-CSS/untitled-ui  -  PushEvent
#
# tanettrimas  -  navikt/sykefravarsstatistikk  -  PullRequestEvent
#
# kimcoleman  -  kimcoleman/convertkit-paid-memberships-pro  -  PushEvent
#
# NaokiTsuchiya  -  alps-asd/app-state-diagram  -  PullRequestEvent
#
# vlukashenko  -  lhcb/starterkit-lessons  -  PushEvent
#
# github-actions[bot]  -  allwaysLove/AutoApiSR  -  PushEvent
#
# ganeshabhi1  -  ganeshabhi1/ETG  -  PushEvent
#
# laurent2207  -  MaastrichtUniversity/mirthconnect-docker  -  DeleteEvent
#
# shyam-j  -  TexasInstruments/edgeai-gst-plugins  -  CreateEvent
#
# waldofx  -  waldofx/Save-the-Seas  -  PushEvent
#
# nat-1501  -  nat-1501/siteNataliSoares  -  CreateEvent
#
# tiltom  -  DistributedCollective/Sovryn-frontend  -  PushEvent
#
# araihC  -  APE-group/wavescalephant  -  PushEvent
#
# vercel[bot]  -  ugurhan-b/AsciiEffect_webpack  -  CommitCommentEvent

# %% [markdown]
# ### Intenational Space Station
#
# Send a simple `get` request to know where the ISS is right now.
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
url = "http://api.open-notify.org/iss-now.json"

# %%
response = requests.get(url)

# %%
response.json()
# Out:
# {'iss_position': {'latitude': '14.4694', 'longitude': '56.3147'},
#  'message': 'success',
#  'timestamp': 1637665913}

# %% [markdown]
# ## Spotipy
#
# Spotify has an API that allows users to gather information about songs and even interact with other users and playlists. To make their usage in Python easier, someone created `spotipy`, a library with some convenient functions to send requests and collect data.
#
# Create / log into an Spotify account (https://developer.spotify.com/dashboard/login) and follow these steps (only the "Register your App" section): https://developer.spotify.com/documentation/general/guides/authorization/app-settings/

# %% [markdown]
# #### Authentification
#
# Follow the wrapper for the API docs: https://spotipy.readthedocs.io/en/2.16.1/

# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\akbar\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: requests>=2.25.0 in c:\users\akbar\anaconda3\lib\site-packages (from spotipy) (2.25.1)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\akbar\anaconda3\lib\site-packages (from spotipy) (1.26.4)
# Requirement already satisfied: six>=1.15.0 in c:\users\akbar\anaconda3\lib\site-packages (from spotipy) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\akbar\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akbar\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\akbar\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (4.0.0)

# %%
# import libraries
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Initialize SpotiPy with user credentias
sp_cr = SpotifyClientCredentials(client_id="8b2e52a68a1a4cc2bd81cf2503b9466d",
                                 client_secret="9ea4397edbeb4b59938094533d25cc1c")

sp = spotipy.Spotify(client_credentials_manager=sp_cr)

# %% [markdown]
# #### Searching songs with 'queries' with `sp.search`
#
# This function allows you to find songs with using Spotify's search engine. That's convenient when you don't have the exact "id" of a song.

# %%
results = sp.search(q="Lady Gaga", limit = 10)

# %% [markdown]
# Explore the object returned by the request. As it's a dictionary (with nested dictionaries inside), using `.keys` is a great way to see what's in there:

# %%
JSON(results)

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
results["tracks"].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %% [markdown]
# This is the url of your request:

# %%
results["tracks"]["href"]
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=10'

# %% [markdown]
# This is the name of the first song returned by the API:

# %%
results["tracks"]["items"][9]["name"]
# Out:
# 'Applause'

# %% [markdown]
# As one song can have many artists, the artists are returned as a list: you know that because the dictionary is wrapped by square brackets.

# %%
results["tracks"]["items"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %% [markdown]
# There are some other interesting features:

# %%
results["tracks"]["items"][0]["popularity"]
# Out:
# 81

# %% [markdown]
# This is how Spotify identifies individual songs: with an `uri`. (the `id` and the `url` are also ways to identify uniquely each song).

# %%
results["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:0SiywuOBRcynK0uKGWdCnn'

# %% [markdown]
# Here we look for 10 songs by the Red Hot Chilli Peppers and store the `uri` of the songs and their names.

# %%
# send request and store the response
red_hot = sp.search(q="Red hot chili peppers", limit=10)

# initialize empty lists to store stuff later
list_of_uri = []
list_of_song_names = []

# iterate through the "items" (the songs), and append
# the "uri" and the "name" to the lists we created
for item in red_hot["tracks"]["items"]:
    list_of_uri.append(item["uri"])
    list_of_song_names.append(item["name"])

# print results
print(list_of_uri)
print("\n")
print(list_of_song_names)
# Out:
# ['spotify:track:3d9DChrdc6BOeFsbrZ3Is0', 'spotify:track:3xJu5hrOU9OvFQSGLQiwQS', 'spotify:track:1Y6DGcTCuMAtw8KB3h4W3q', 'spotify:track:3ZOEytgrvLwQaqXreDs2Jx', 'spotify:track:0Kojfmpnf0A2yC1zyv39Zx', 'spotify:track:1XxCiPw07rd1ytYnE7SoJI', 'spotify:track:48UPSzbZjgc449aqz8bxox', 'spotify:track:4nRi0PlIpoy9SyySD1IDGY', 'spotify:track:2aibwv5hGXSgw7Yru8IYTO', 'spotify:track:4dzbGvxqQ1DsF6m6RUlPwg']
#
#
# ['Under the Bridge', 'Anthony Kiedis', 'Around the World', "Can't Stop", 'Buried Alive', "Road Trippin'", 'Californication', 'By the Way - Live', 'Snow (Hey Oh)', 'Pedigree']

# %% [markdown]
# #### Searching multiple artists
#
# Here we first create a list of artists we want to gather songs from. Then we iterate through them and append the results into a big list called `results`.

# %%
artists = ["Red hot chili peppers", "SCARR", "Whitney Houston"]

# %%
results = []

for artist in artists:
    results.append(sp.search(q=artist, limit=10))

# %%
results
# Out:
# [{'tracks': {'href': 'https://api.spotify.com/v1/search?query=Red+hot+chili+peppers&type=track&offset=0&limit=10',
#    'items': [{'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#         'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#         'id': '0L8ExT028jH3ddEcZwqJJ5',
#         'name': 'Red Hot Chili Peppers',
#         'type': 'artist',
#         'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TR',
#        'TT',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/30Perjew8HyGkdSmqguYyg'},
#       'href': 'https://api.spotify.com/v1/albums/30Perjew8HyGkdSmqguYyg',
#       'id': '30Perjew8HyGkdSmqguYyg',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273153d79816d853f2694b2cc70',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02153d79816d853f2694b2cc70',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851153d79816d853f2694b2cc70',
#         'width': 64}],
#       'name': 'Blood Sugar Sex Magik (Deluxe Edition)',
#       'release_date': '1991-09-24',
#       'release_date_precision': 'day',
#       'total_tracks': 19,
#       'type': 'album',
#       'uri': 'spotify:album:30Perjew8HyGkdSmqguYyg'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 264306,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWB19901576'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3d9DChrdc6BOeFsbrZ3Is0'},
#      'href': 'https://api.spotify.com/v1/tracks/3d9DChrdc6BOeFsbrZ3Is0',
#      'id': '3d9DChrdc6BOeFsbrZ3Is0',
#      'is_local': False,
#      'name': 'Under the Bridge',
#      'popularity': 81,
#      'preview_url': 'https://p.scdn.co/mp3-preview/90e41778392f27b6f7dd82db4c90916b3727aa6a?cid=8b2e52a68a1a4cc2bd81cf2503b9466d',
#      'track_number': 11,
#      'type': 'track',
#      'uri': 'spotify:track:3d9DChrdc6BOeFsbrZ3Is0'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0NB5HROxc8dDBXpkIi1v3d'},
#         'href': 'https://api.spotify.com/v1/artists/0NB5HROxc8dDBXpkIi1v3d',
#         'id': '0NB5HROxc8dDBXpkIi1v3d',
#         'name': 'Remi Wolf',
#         'type': 'artist',
#         'uri': 'spotify:artist:0NB5HROxc8dDBXpkIi1v3d'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7tJ8Wtej161vR0uCbGDiDR'},
#       'href': 'https://api.spotify.com/v1/albums/7tJ8Wtej161vR0uCbGDiDR',
#       'id': '7tJ8Wtej161vR0uCbGDiDR',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27316a6cb93e32bf2ae66b1f5b2',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0216a6cb93e32bf2ae66b1f5b2',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485116a6cb93e32bf2ae66b1f5b2',
#         'width': 64}],
#       'name': 'Juno',
#       'release_date': '2021-10-15',
#       'release_date_precision': 'day',
#       'total_tracks': 13,
#       'type': 'album',
#       'uri': 'spotify:album:7tJ8Wtej161vR0uCbGDiDR'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0NB5HROxc8dDBXpkIi1v3d'},
#        'href': 'https://api.spotify.com/v1/artists/0NB5HROxc8dDBXpkIi1v3d',
#        'id': '0NB5HROxc8dDBXpkIi1v3d',
#        'name': 'Remi Wolf',
#        'type': 'artist',
#        'uri': 'spotify:artist:0NB5HROxc8dDBXpkIi1v3d'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 171897,
#      'explicit': False,
#      'external_ids': {'isrc': 'USUG12103572'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3xJu5hrOU9OvFQSGLQiwQS'},
#      'href': 'https://api.spotify.com/v1/tracks/3xJu5hrOU9OvFQSGLQiwQS',
#      'id': '3xJu5hrOU9OvFQSGLQiwQS',
#      'is_local': False,
#      'name': 'Anthony Kiedis',
#      'popularity': 60,
#      'preview_url': None,
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:3xJu5hrOU9OvFQSGLQiwQS'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#         'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#         'id': '0L8ExT028jH3ddEcZwqJJ5',
#         'name': 'Red Hot Chili Peppers',
#         'type': 'artist',
#         'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TR',
#        'TT',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/0fLhefnjlIV3pGNF9Wo8CD'},
#       'href': 'https://api.spotify.com/v1/albums/0fLhefnjlIV3pGNF9Wo8CD',
#       'id': '0fLhefnjlIV3pGNF9Wo8CD',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273a9249ebb15ca7a5b75f16a90',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02a9249ebb15ca7a5b75f16a90',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851a9249ebb15ca7a5b75f16a90',
#         'width': 64}],
#       'name': 'Californication',
#       'release_date': '1999-06-08',
#       'release_date_precision': 'day',
#       'total_tracks': 15,
#       'type': 'album',
#       'uri': 'spotify:album:0fLhefnjlIV3pGNF9Wo8CD'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 239213,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWB19900687'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1Y6DGcTCuMAtw8KB3h4W3q'},
#      'href': 'https://api.spotify.com/v1/tracks/1Y6DGcTCuMAtw8KB3h4W3q',
#      'id': '1Y6DGcTCuMAtw8KB3h4W3q',
#      'is_local': False,
#      'name': 'Around the World',
#      'popularity': 51,
#      'preview_url': 'https://p.scdn.co/mp3-preview/79ddc3851069cf64e6b11574b7414477ddf275d6?cid=8b2e52a68a1a4cc2bd81cf2503b9466d',
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:1Y6DGcTCuMAtw8KB3h4W3q'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#         'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#         'id': '0L8ExT028jH3ddEcZwqJJ5',
#         'name': 'Red Hot Chili Peppers',
#         'type': 'artist',
#         'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TR',
#        'TT',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/6deiaArbeoqp1xPEGdEKp1'},
#       'href': 'https://api.spotify.com/v1/albums/6deiaArbeoqp1xPEGdEKp1',
#       'id': '6deiaArbeoqp1xPEGdEKp1',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273de1af2785a83cc660155a0c4',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02de1af2785a83cc660155a0c4',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851de1af2785a83cc660155a0c4',
#         'width': 64}],
#       'name': 'By the Way (Deluxe Edition)',
#       'release_date': '2002-07-09',
#       'release_date_precision': 'day',
#       'total_tracks': 18,
#       'type': 'album',
#       'uri': 'spotify:album:6deiaArbeoqp1xPEGdEKp1'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 269000,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWB10201694'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3ZOEytgrvLwQaqXreDs2Jx'},
#      'href': 'https://api.spotify.com/v1/tracks/3ZOEytgrvLwQaqXreDs2Jx',
#      'id': '3ZOEytgrvLwQaqXreDs2Jx',
#      'is_local': False,
#      'name': "Can't Stop",
#      'popularity': 80,
#      'preview_url': 'https://p.scdn.co/mp3-preview/076f7d75404dfd18964d60da63d1855b192f3e62?cid=8b2e52a68a1a4cc2bd81cf2503b9466d',
#      'track_number': 7,
#      'type': 'track',
#      'uri': 'spotify:track:3ZOEytgrvLwQaqXreDs2Jx'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xRYI6VqpkE3UwrDrAZL8L'},
#         'href': 'https://api.spotify.com/v1/artists/4xRYI6VqpkE3UwrDrAZL8L',
#         'id': '4xRYI6VqpkE3UwrDrAZL8L',
#         'name': 'Logic',
#         'type': 'artist',
#         'uri': 'spotify:artist:4xRYI6VqpkE3UwrDrAZL8L'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1Mk7Lei0Ra3hawezqmad5V'},
#       'href': 'https://api.spotify.com/v1/albums/1Mk7Lei0Ra3hawezqmad5V',
#       'id': '1Mk7Lei0Ra3hawezqmad5V',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273a4c35326f6fe6676c10e31ac',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02a4c35326f6fe6676c10e31ac',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851a4c35326f6fe6676c10e31ac',
#         'width': 64}],
#       'name': 'Under Pressure (Deluxe)',
#       'release_date': '2014-10-21',
#       'release_date_precision': 'day',
#       'total_tracks': 15,
#       'type': 'album',
#       'uri': 'spotify:album:1Mk7Lei0Ra3hawezqmad5V'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xRYI6VqpkE3UwrDrAZL8L'},
#        'href': 'https://api.spotify.com/v1/artists/4xRYI6VqpkE3UwrDrAZL8L',
#        'id': '4xRYI6VqpkE3UwrDrAZL8L',
#        'name': 'Logic',
#        'type': 'artist',
#        'uri': 'spotify:artist:4xRYI6VqpkE3UwrDrAZL8L'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 337746,
#      'explicit': True,
#      'external_ids': {'isrc': 'USUM71414218'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0Kojfmpnf0A2yC1zyv39Zx'},
#      'href': 'https://api.spotify.com/v1/tracks/0Kojfmpnf0A2yC1zyv39Zx',
#      'id': '0Kojfmpnf0A2yC1zyv39Zx',
#      'is_local': False,
#      'name': 'Buried Alive',
#      'popularity': 53,
#      'preview_url': None,
#      'track_number': 5,
#      'type': 'track',
#      'uri': 'spotify:track:0Kojfmpnf0A2yC1zyv39Zx'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#         'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#         'id': '0L8ExT028jH3ddEcZwqJJ5',
#         'name': 'Red Hot Chili Peppers',
#         'type': 'artist',
#         'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TR',
#        'TT',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2Y9IRtehByVkegoD7TcLfi'},
#       'href': 'https://api.spotify.com/v1/albums/2Y9IRtehByVkegoD7TcLfi',
#       'id': '2Y9IRtehByVkegoD7TcLfi',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27394d08ab63e57b0cae74e8595',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0294d08ab63e57b0cae74e8595',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485194d08ab63e57b0cae74e8595',
#         'width': 64}],
#       'name': 'Californication (Deluxe Edition)',
#       'release_date': '1999-06-08',
#       'release_date_precision': 'day',
#       'total_tracks': 18,
#       'type': 'album',
#       'uri': 'spotify:album:2Y9IRtehByVkegoD7TcLfi'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 204973,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWB19900700'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1XxCiPw07rd1ytYnE7SoJI'},
#      'href': 'https://api.spotify.com/v1/tracks/1XxCiPw07rd1ytYnE7SoJI',
#      'id': '1XxCiPw07rd1ytYnE7SoJI',
#      'is_local': False,
#      'name': "Road Trippin'",
#      'popularity': 61,
#      'preview_url': 'https://p.scdn.co/mp3-preview/44653117c32f12cb2af30093736571893ff4c694?cid=8b2e52a68a1a4cc2bd81cf2503b9466d',
#      'track_number': 15,
#      'type': 'track',
#      'uri': 'spotify:track:1XxCiPw07rd1ytYnE7SoJI'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#         'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#         'id': '0L8ExT028jH3ddEcZwqJJ5',
#         'name': 'Red Hot Chili Peppers',
#         'type': 'artist',
#         'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TR',
#        'TT',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2Y9IRtehByVkegoD7TcLfi'},
#       'href': 'https://api.spotify.com/v1/albums/2Y9IRtehByVkegoD7TcLfi',
#       'id': '2Y9IRtehByVkegoD7TcLfi',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27394d08ab63e57b0cae74e8595',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0294d08ab63e57b0cae74e8595',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485194d08ab63e57b0cae74e8595',
#         'width': 64}],
#       'name': 'Californication (Deluxe Edition)',
#       'release_date': '1999-06-08',
#       'release_date_precision': 'day',
#       'total_tracks': 18,
#       'type': 'album',
#       'uri': 'spotify:album:2Y9IRtehByVkegoD7TcLfi'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 329733,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWB19900690'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/48UPSzbZjgc449aqz8bxox'},
#      'href': 'https://api.spotify.com/v1/tracks/48UPSzbZjgc449aqz8bxox',
#      'id': '48UPSzbZjgc449aqz8bxox',
#      'is_local': False,
#      'name': 'Californication',
#      'popularity': 81,
#      'preview_url': 'https://p.scdn.co/mp3-preview/175ce440229d2fb5361756f3e68c9647b86a8eee?cid=8b2e52a68a1a4cc2bd81cf2503b9466d',
#      'track_number': 6,
#      'type': 'track',
#      'uri': 'spotify:track:48UPSzbZjgc449aqz8bxox'},
#     {'album': {'album_type': 'compilation',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#         'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#         'id': '0LyfQWJT6nXafLPZqxe9Of',
#         'name': 'Various Artists',
#         'type': 'artist',
#         'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#       'available_markets': ['CA', 'US'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/4US5ARBYbzQI177Tc5J37t'},
#       'href': 'https://api.spotify.com/v1/albums/4US5ARBYbzQI177Tc5J37t',
#       'id': '4US5ARBYbzQI177Tc5J37t',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273c2244fca50540dc4df3b6bbf',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02c2244fca50540dc4df3b6bbf',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851c2244fca50540dc4df3b6bbf',
#         'width': 64}],
#       'name': 'The Rock & Roll Hall Of Fame: In Concert 2012 & 2013 (Live)',
#       'release_date': '2018-04-24',
#       'release_date_precision': 'day',
#       'total_tracks': 22,
#       'type': 'album',
#       'uri': 'spotify:album:4US5ARBYbzQI177Tc5J37t'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['CA', 'US'],
#      'disc_number': 1,
#      'duration_ms': 217351,
#      'explicit': False,
#      'external_ids': {'isrc': 'USYRC1800031'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4nRi0PlIpoy9SyySD1IDGY'},
#      'href': 'https://api.spotify.com/v1/tracks/4nRi0PlIpoy9SyySD1IDGY',
#      'id': '4nRi0PlIpoy9SyySD1IDGY',
#      'is_local': False,
#      'name': 'By the Way - Live',
#      'popularity': 10,
#      'preview_url': 'https://p.scdn.co/mp3-preview/e073ea994d91d77841fee33c8db3e1d76850beea?cid=8b2e52a68a1a4cc2bd81cf2503b9466d',
#      'track_number': 10,
#      'type': 'track',
#      'uri': 'spotify:track:4nRi0PlIpoy9SyySD1IDGY'},
#     {'album': {'album_type': 'album',
# ...
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 277240,
#      'explicit': False,
#      'external_ids': {'isrc': 'USAR18500147'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0t6DdFmFQhQYWhmfa5FJer'},
#      'href': 'https://api.spotify.com/v1/tracks/0t6DdFmFQhQYWhmfa5FJer',
#      'id': '0t6DdFmFQhQYWhmfa5FJer',
#      'is_local': False,
#      'name': 'You Give Good Love',
#      'popularity': 52,
#      'preview_url': 'https://p.scdn.co/mp3-preview/dc77dfeffba6def27cfaec208623ab82cc33cacc?cid=8b2e52a68a1a4cc2bd81cf2503b9466d',
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:0t6DdFmFQhQYWhmfa5FJer'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XpaIBNiVzIetEPCWDvAFP'},
#         'href': 'https://api.spotify.com/v1/artists/6XpaIBNiVzIetEPCWDvAFP',
#         'id': '6XpaIBNiVzIetEPCWDvAFP',
#         'name': 'Whitney Houston',
#         'type': 'artist',
#         'uri': 'spotify:artist:6XpaIBNiVzIetEPCWDvAFP'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2MH37enG6IPvNK5QFLyKes'},
#       'href': 'https://api.spotify.com/v1/albums/2MH37enG6IPvNK5QFLyKes',
#       'id': '2MH37enG6IPvNK5QFLyKes',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2732ae4fcec560ab559d6f5dc88',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e022ae4fcec560ab559d6f5dc88',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048512ae4fcec560ab559d6f5dc88',
#         'width': 64}],
#       'name': 'Whitney Houston',
#       'release_date': '1985-02-14',
#       'release_date_precision': 'day',
#       'total_tracks': 10,
#       'type': 'album',
#       'uri': 'spotify:album:2MH37enG6IPvNK5QFLyKes'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XpaIBNiVzIetEPCWDvAFP'},
#        'href': 'https://api.spotify.com/v1/artists/6XpaIBNiVzIetEPCWDvAFP',
#        'id': '6XpaIBNiVzIetEPCWDvAFP',
#        'name': 'Whitney Houston',
#        'type': 'artist',
#        'uri': 'spotify:artist:6XpaIBNiVzIetEPCWDvAFP'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 275533,
#      'explicit': False,
#      'external_ids': {'isrc': 'USAR18500150'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5tdKaKLnC4SgtDZ6RlWeal'},
#      'href': 'https://api.spotify.com/v1/tracks/5tdKaKLnC4SgtDZ6RlWeal',
#      'id': '5tdKaKLnC4SgtDZ6RlWeal',
#      'is_local': False,
#      'name': 'How Will I Know',
#      'popularity': 70,
#      'preview_url': 'https://p.scdn.co/mp3-preview/4cfd0ab2b770e37313275d37788f687992b0ee17?cid=8b2e52a68a1a4cc2bd81cf2503b9466d',
#      'track_number': 6,
#      'type': 'track',
#      'uri': 'spotify:track:5tdKaKLnC4SgtDZ6RlWeal'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XpaIBNiVzIetEPCWDvAFP'},
#         'href': 'https://api.spotify.com/v1/artists/6XpaIBNiVzIetEPCWDvAFP',
#         'id': '6XpaIBNiVzIetEPCWDvAFP',
#         'name': 'Whitney Houston',
#         'type': 'artist',
#         'uri': 'spotify:artist:6XpaIBNiVzIetEPCWDvAFP'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/5Vdzprr5cOqXQo44eHeV7t'},
#       'href': 'https://api.spotify.com/v1/albums/5Vdzprr5cOqXQo44eHeV7t',
#       'id': '5Vdzprr5cOqXQo44eHeV7t',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273cc57e9b00b87dd0f6e868347',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02cc57e9b00b87dd0f6e868347',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851cc57e9b00b87dd0f6e868347',
#         'width': 64}],
#       'name': 'Whitney',
#       'release_date': '1987-06-02',
#       'release_date_precision': 'day',
#       'total_tracks': 11,
#       'type': 'album',
#       'uri': 'spotify:album:5Vdzprr5cOqXQo44eHeV7t'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XpaIBNiVzIetEPCWDvAFP'},
#        'href': 'https://api.spotify.com/v1/artists/6XpaIBNiVzIetEPCWDvAFP',
#        'id': '6XpaIBNiVzIetEPCWDvAFP',
#        'name': 'Whitney Houston',
#        'type': 'artist',
#        'uri': 'spotify:artist:6XpaIBNiVzIetEPCWDvAFP'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 305066,
#      'explicit': False,
#      'external_ids': {'isrc': 'USAR18700115'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/19wadMw1A8XejDV4p5wMt1'},
#      'href': 'https://api.spotify.com/v1/tracks/19wadMw1A8XejDV4p5wMt1',
#      'id': '19wadMw1A8XejDV4p5wMt1',
#      'is_local': False,
#      'name': "Didn't We Almost Have It All",
#      'popularity': 61,
#      'preview_url': 'https://p.scdn.co/mp3-preview/7411cc6a36f98f46a2890f6f322605021db0f3c2?cid=8b2e52a68a1a4cc2bd81cf2503b9466d',
#      'track_number': 4,
#      'type': 'track',
#      'uri': 'spotify:track:19wadMw1A8XejDV4p5wMt1'}],
#    'limit': 10,
#    'next': 'https://api.spotify.com/v1/search?query=Whitney+Houston&type=track&offset=10&limit=10',
#    'offset': 0,
#    'previous': None,
#    'total': 5827}}]

# %% [markdown]
# We can iterate through the `results` list and get the names of all the songs:

# %%
song_names = []

for result in results:
    for item in result["tracks"]["items"]:
        song_names.append(item["name"])

# %%
song_names
# Out:
# ['Under the Bridge',
#  'Anthony Kiedis',
#  'Around the World',
#  "Can't Stop",
#  'Buried Alive',
#  "Road Trippin'",
#  'Californication',
#  'By the Way - Live',
#  'Snow (Hey Oh)',
#  'Pedigree',
#  'Scarred From Love',
#  'Emotionally Scarred',
#  'SCARR',
#  'Scarred',
#  'SoIcyBoyz 2 (feat. Pooh Shiesty, Foogiano & Tay Keith)',
#  'Scarred Island',
#  'SoIcyBoyz 2 (feat. Pooh Shiesty, Foogiano & Tay Keith)',
#  'Scarred',
#  'Rolling Loud (feat. Big Scarr, BigWalkDog)',
#  'Free Smoke (feat. Big Scarr)',
#  'I Wanna Dance with Somebody (Who Loves Me)',
#  'The Star Spangled Banner (feat. The Florida Orchestra) - Live from Super Bowl XXV',
#  'Higher Love',
#  'I Look to You',
#  'I Will Always Love You',
#  'Exhale (Shoop Shoop) - from "Waiting to Exhale" - Original Soundtrack',
#  'I Have Nothing',
#  'You Give Good Love',
#  'How Will I Know',
#  "Didn't We Almost Have It All"]

# %% [markdown]
# #### Exploring the tracks

# %%
# Get artist id's for all the tracks you found

query = "Despacito"

Despacito = sp.search(q = query, limit = 50)

# %%
Despacito_artists = set()

for item in Despacito["tracks"]["items"]:
    for artist in item["artists"]:
        Despacito_artists.add(artist["uri"])

# %%
JSON(Despacito)

# %%
Despacito["tracks"]["items"][2]["artists"][0]["name"]
# Out:
# 'Luis Fonsi'

# %%
Despacito_artists
# Out:
# {'spotify:artist:0NxhAEPOSeCg6vypFr7yjU',
#  'spotify:artist:0QNakySWugkMvfwbDoaY9L',
#  'spotify:artist:0fIdQWpwzU2oEtsoyArDOL',
#  'spotify:artist:0r3y7sISJoUIfT5E85AYII',
#  'spotify:artist:1NiC1V6xc8OR1ERiIoCvtx',
#  'spotify:artist:1Uz4WPsI4VylKT6lhJiDO5',
#  'spotify:artist:1emgbX82aLN8eCS3AnXFfC',
#  'spotify:artist:1mX1TWKpNxDSAH16LgDfiR',
#  'spotify:artist:1qwVM2JnEMXbKgvZESGsRn',
#  'spotify:artist:1rVo9h17cHhWerDiZj0yXH',
#  'spotify:artist:1sJhbiQRSIKZeTYEZfzBSV',
#  'spotify:artist:1uNFoZAHBGtllmzznpCI3s',
#  'spotify:artist:1uj8EOCKAXn4w2TR7CVnQb',
#  'spotify:artist:26AHtbjWKiwYzsoGoUZq53',
#  'spotify:artist:2T06whb4s6UiufL1j5Qtz9',
#  'spotify:artist:2VAjBQ6cM2faT2UKxONV93',
#  'spotify:artist:3YfvowVavHTzXLKmKaYM1c',
#  'spotify:artist:3YrM00mKs7wqOtBPmeSoEo',
#  'spotify:artist:3vOJJbGGUOtC9csissiL0G',
#  'spotify:artist:4KLOMib6zqzNayKwLWTs2Q',
#  'spotify:artist:4L5SLCIDWPPNGzrLraYCOS',
#  'spotify:artist:4N5fp4zhTsVITZTVfsXpc2',
#  'spotify:artist:4V8Sr092TqfHkfAA5fXXqG',
#  'spotify:artist:4VMYDCV2IEDYJArk749S6m',
#  'spotify:artist:4fdxbJLSNRIMkMGbLs5QPF',
#  'spotify:artist:4j4Lq1ut4h3H3eTIubtyog',
#  'spotify:artist:5DsbNI5ZIDIWjmsAdaYvZ2',
#  'spotify:artist:5HPu6u2rDA0f6jp51xZAEq',
#  'spotify:artist:5KWOCu1saEHAhPiLKlOLIy',
#  'spotify:artist:5tqJLLaSDpdhDAwqWgAdXM',
#  'spotify:artist:62rnGiDozQmBBk5yM21yOC',
#  'spotify:artist:6Fi8CHfO8WGtu3yO8c2Mc4',
#  'spotify:artist:6MERXsiRbur2oJZFgYRDKz',
#  'spotify:artist:6QtqvuYuaOJy4te3nfkHKK',
#  'spotify:artist:6RTlv2UCWtRggV0rIo5TrN',
#  'spotify:artist:6U3ybJ9UHNKEdsH7ktGBZ7',
#  'spotify:artist:6dBIk14xcZqU0cRsyjXNkX',
#  'spotify:artist:6mU8ucezzms5I2kNH6HNlu',
#  'spotify:artist:6wBOZ9D65AcqUlfKUqsQ7R',
#  'spotify:artist:72iuahEAHKaMzDXKVw6e8P',
#  'spotify:artist:738wLrAtLtCtFOLvQBXOXp',
#  'spotify:artist:7CQwac16i1W5ej8YpuL3dv',
#  'spotify:artist:7dTPvuNcEXLkQ1XiAuiWIP',
#  'spotify:artist:7p3ipw2PvGG0X2x6zL1DLO',
#  'spotify:artist:7y33enVLfDvft6HGNmcxdV'}

# %% [markdown]
# ### Playlists

# %%
my_playlist = sp.user_playlist_tracks(user="spotify",
                                      playlist_id="https://open.spotify.com/playlist/24T3swe0HN7JWLfsDcakHw?si=ce24270cef314a9a")

# %% [markdown]
# Extract all songs IDs from a playlist

# %%
JSON(my_playlist)

# %%
my_playlist["items"][1]["track"]["uri"]
# Out:
# 'spotify:track:5eS6pTvDNOvh2kyxeZtK3r'

# %% [markdown]
# ### Audio features
#
# You can check here an explanation of the audio features: https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/

# %%
sp.audio_features("spotify:track:5eS6pTvDNOvh2kyxeZtK3r")
# Out:
# [{'danceability': 0.479,
#   'energy': 0.678,
#   'key': 2,
#   'loudness': -12.17,
#   'mode': 1,
#   'speechiness': 0.0758,
#   'acousticness': 0.00018,
#   'instrumentalness': 0.661,
#   'liveness': 0.421,
#   'valence': 0.227,
#   'tempo': 116.033,
#   'type': 'audio_features',
#   'id': '5eS6pTvDNOvh2kyxeZtK3r',
#   'uri': 'spotify:track:5eS6pTvDNOvh2kyxeZtK3r',
#   'track_href': 'https://api.spotify.com/v1/tracks/5eS6pTvDNOvh2kyxeZtK3r',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5eS6pTvDNOvh2kyxeZtK3r',
#   'duration_ms': 387507,
#   'time_signature': 4}]

# %% [markdown]
# ### Exercise: Create a function that takes a song name and returns its audio features

# %%
def get_audio_feat_song(song_name):
    result = sp.search(q=song_name, limit=1)
    uri = result["tracks"]["items"][0]["uri"]
    return sp.audio_features(uri)

get_audio_feat_song(Numb)
# Out:
# [{'danceability': 0.502,
#   'energy': 0.333,
#   'key': 7,
#   'loudness': -10.914,
#   'mode': 1,
#   'speechiness': 0.0264,
#   'acousticness': 0.699,
#   'instrumentalness': 0,
#   'liveness': 0.222,
#   'valence': 0.729,
#   'tempo': 96.982,
#   'type': 'audio_features',
#   'id': '6QyQmdvQ1ywNccYa0pwLNQ',
#   'uri': 'spotify:track:6QyQmdvQ1ywNccYa0pwLNQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6QyQmdvQ1ywNccYa0pwLNQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6QyQmdvQ1ywNccYa0pwLNQ',
#   'duration_ms': 174360,
#   'time_signature': 4}]

# %% [markdown]
# ### Exercise: Collect a big dataframe of songs with their audio features
#
# - Start by looking for a playlist on spotify (it does not have ot be your playlist), and copy its url.
#
# - Extract the audio features for each song on your playlist.
#
# - Now collect the link of many playlists and do the same for all of them.
#
# - Structure the information as a dataframe where each row is a song and the columns are audio features.

# %%
playlists = ["https://open.spotify.com/playlist/0ce6Rmxf7QXroqa1wzjWY8?si=05b8e416dedd4894",
             "https://open.spotify.com/playlist/2PjVPkj4a9kBvQIXaZ6UUt?si=c83fe4d8a4974095",
             "https://open.spotify.com/playlist/1h0CEZCm6IbFTbxThn6Xcs?si=549db4d4f4ca4c18",
             "https://open.spotify.com/playlist/37i9dQZF1DX7Mq3mO5SSDc?si=55c443251302424e"
            ]

# %%
results = []

for p in playlists:
    results.append(sp.playlist_tracks(p))

# %%
results[0]["items"]
# Out:
# [{'added_at': '2021-09-22T07:34:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#    'href': 'https://api.spotify.com/v1/users/gperdigo',
#    'id': 'gperdigo',
#    'type': 'user',
#    'uri': 'spotify:user:gperdigo'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/579T5fNgfbDetyamUTAetw'},
#       'href': 'https://api.spotify.com/v1/artists/579T5fNgfbDetyamUTAetw',
#       'id': '579T5fNgfbDetyamUTAetw',
#       'name': 'S+C+A+R+R',
#       'type': 'artist',
#       'uri': 'spotify:artist:579T5fNgfbDetyamUTAetw'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5ZwTPVgvwIMxJh2GAdsaaP'},
#     'href': 'https://api.spotify.com/v1/albums/5ZwTPVgvwIMxJh2GAdsaaP',
#     'id': '5ZwTPVgvwIMxJh2GAdsaaP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27331df83ec065ed0a42cc82670',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0231df83ec065ed0a42cc82670',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485131df83ec065ed0a42cc82670',
#       'width': 64}],
#     'name': 'You\'re the One (From "I Lost My Body")',
#     'release_date': '2019-10-31',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5ZwTPVgvwIMxJh2GAdsaaP'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/579T5fNgfbDetyamUTAetw'},
#      'href': 'https://api.spotify.com/v1/artists/579T5fNgfbDetyamUTAetw',
#      'id': '579T5fNgfbDetyamUTAetw',
#      'name': 'S+C+A+R+R',
#      'type': 'artist',
#      'uri': 'spotify:artist:579T5fNgfbDetyamUTAetw'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 167986,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FR6F31902770'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5Tnx4R7Gwj1LZsfssfzchh'},
#    'href': 'https://api.spotify.com/v1/tracks/5Tnx4R7Gwj1LZsfssfzchh',
#    'id': '5Tnx4R7Gwj1LZsfssfzchh',
#    'is_local': False,
#    'name': 'You\'re the One - From "I Lost My Body"',
#    'popularity': 37,
#    'preview_url': 'https://p.scdn.co/mp3-preview/95301c6db23d3e35deda12970ef6bdc9f2d71579?cid=8b2e52a68a1a4cc2bd81cf2503b9466d',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5Tnx4R7Gwj1LZsfssfzchh'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-22T07:35:32Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#    'href': 'https://api.spotify.com/v1/users/gperdigo',
#    'id': 'gperdigo',
#    'type': 'user',
#    'uri': 'spotify:user:gperdigo'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5wFXmYsg3KFJ8BDsQudJ4f'},
#       'href': 'https://api.spotify.com/v1/artists/5wFXmYsg3KFJ8BDsQudJ4f',
#       'id': '5wFXmYsg3KFJ8BDsQudJ4f',
#       'name': 'Manchester Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:5wFXmYsg3KFJ8BDsQudJ4f'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4hruYceqit29o6m4arpAql'},
#     'href': 'https://api.spotify.com/v1/albums/4hruYceqit29o6m4arpAql',
#     'id': '4hruYceqit29o6m4arpAql',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736827146a676dafc0357fa665',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026827146a676dafc0357fa665',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516827146a676dafc0357fa665',
#       'width': 64}],
#     'name': 'A Black Mile To The Surface',
#     'release_date': '2017-07-28',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:4hruYceqit29o6m4arpAql'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5wFXmYsg3KFJ8BDsQudJ4f'},
#      'href': 'https://api.spotify.com/v1/artists/5wFXmYsg3KFJ8BDsQudJ4f',
#      'id': '5wFXmYsg3KFJ8BDsQudJ4f',
#      'name': 'Manchester Orchestra',
#      'type': 'artist',
#      'uri': 'spotify:artist:5wFXmYsg3KFJ8BDsQudJ4f'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 328933,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USC4R1702133'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5eKfpH2dQ7FltCqb7LWEGJ'},
#    'href': 'https://api.spotify.com/v1/tracks/5eKfpH2dQ7FltCqb7LWEGJ',
#    'id': '5eKfpH2dQ7FltCqb7LWEGJ',
#    'is_local': False,
#    'name': 'The Alien',
#    'popularity': 47,
#    'preview_url': None,
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:5eKfpH2dQ7FltCqb7LWEGJ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-22T07:35:42Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#    'href': 'https://api.spotify.com/v1/users/gperdigo',
#    'id': 'gperdigo',
#    'type': 'user',
#    'uri': 'spotify:user:gperdigo'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YwaTXvuTkyUrGPbz4jEYg'},
#       'href': 'https://api.spotify.com/v1/artists/4YwaTXvuTkyUrGPbz4jEYg',
#       'id': '4YwaTXvuTkyUrGPbz4jEYg',
#       'name': 'Nina And Frederik',
#       'type': 'artist',
#       'uri': 'spotify:artist:4YwaTXvuTkyUrGPbz4jEYg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/63obBSI5HlMFoawrrq8RDG'},
#     'href': 'https://api.spotify.com/v1/albums/63obBSI5HlMFoawrrq8RDG',
#     'id': '63obBSI5HlMFoawrrq8RDG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a287436c88bfedf3892dcaea',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a287436c88bfedf3892dcaea',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a287436c88bfedf3892dcaea',
#       'width': 64}],
#     'name': 'Vintage World Nº10- EPs Collectors "Oh, Pecador" "Oh, Sinner Man"',
#     'release_date': '1958-05-06',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:63obBSI5HlMFoawrrq8RDG'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YwaTXvuTkyUrGPbz4jEYg'},
#      'href': 'https://api.spotify.com/v1/artists/4YwaTXvuTkyUrGPbz4jEYg',
#      'id': '4YwaTXvuTkyUrGPbz4jEYg',
#      'name': 'Nina And Frederik',
#      'type': 'artist',
#      'uri': 'spotify:artist:4YwaTXvuTkyUrGPbz4jEYg'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 145773,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USA560979249'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0R3OcHrzq3f8raukyZgTAc'},
#    'href': 'https://api.spotify.com/v1/tracks/0R3OcHrzq3f8raukyZgTAc',
#    'id': '0R3OcHrzq3f8raukyZgTAc',
#    'is_local': False,
#    'name': 'Oh, Pecador (Oh, Sinne Man)',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/5a1f140ce93647c88b874627f0515bc739aae64a?cid=8b2e52a68a1a4cc2bd81cf2503b9466d',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0R3OcHrzq3f8raukyZgTAc'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-22T07:36:25Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#    'href': 'https://api.spotify.com/v1/users/gperdigo',
#    'id': 'gperdigo',
#    'type': 'user',
#    'uri': 'spotify:user:gperdigo'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2G7QgTep5IsJHGHm1hXygD'},
#       'href': 'https://api.spotify.com/v1/artists/2G7QgTep5IsJHGHm1hXygD',
#       'id': '2G7QgTep5IsJHGHm1hXygD',
#       'name': 'Kid Francescoli',
#       'type': 'artist',
#       'uri': 'spotify:artist:2G7QgTep5IsJHGHm1hXygD'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4iII9nfzjxOYQFp8PyV6HD'},
#     'href': 'https://api.spotify.com/v1/albums/4iII9nfzjxOYQFp8PyV6HD',
#     'id': '4iII9nfzjxOYQFp8PyV6HD',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737fc1ed797a7ef1dd805b5bc5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027fc1ed797a7ef1dd805b5bc5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517fc1ed797a7ef1dd805b5bc5',
#       'width': 64}],
#     'name': 'Play Me Again',
#     'release_date': '2017-03-03',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:4iII9nfzjxOYQFp8PyV6HD'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2G7QgTep5IsJHGHm1hXygD'},
#      'href': 'https://api.spotify.com/v1/artists/2G7QgTep5IsJHGHm1hXygD',
#      'id': '2G7QgTep5IsJHGHm1hXygD',
#      'name': 'Kid Francescoli',
#      'type': 'artist',
#      'uri': 'spotify:artist:2G7QgTep5IsJHGHm1hXygD'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 390638,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FRP621600280'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/24upABZ8A0sAepfu91sEYr'},
#    'href': 'https://api.spotify.com/v1/tracks/24upABZ8A0sAepfu91sEYr',
#    'id': '24upABZ8A0sAepfu91sEYr',
#    'is_local': False,
#    'name': 'Moon (And It Went Like)',
#    'popularity': 69,
#    'preview_url': 'https://p.scdn.co/mp3-preview/dcad19ab187c730cb3ad678695db21baf0137ac2?cid=8b2e52a68a1a4cc2bd81cf2503b9466d',
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:24upABZ8A0sAepfu91sEYr'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-22T07:36:45Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#    'href': 'https://api.spotify.com/v1/users/gperdigo',
#    'id': 'gperdigo',
#    'type': 'user',
#    'uri': 'spotify:user:gperdigo'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aEnNH9PuU1HF3TsZTru54'},
#       'href': 'https://api.spotify.com/v1/artists/4aEnNH9PuU1HF3TsZTru54',
#       'id': '4aEnNH9PuU1HF3TsZTru54',
#       'name': 'Caribou',
#       'type': 'artist',
#       'uri': 'spotify:artist:4aEnNH9PuU1HF3TsZTru54'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1NqhnYAVqlHuPG2OlgKSZy'},
#     'href': 'https://api.spotify.com/v1/albums/1NqhnYAVqlHuPG2OlgKSZy',
#     'id': '1NqhnYAVqlHuPG2OlgKSZy',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273db02bfcbd6808d71afb2a3bf',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02db02bfcbd6808d71afb2a3bf',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851db02bfcbd6808d71afb2a3bf',
#       'width': 64}],
#     'name': 'Never Come Back',
#     'release_date': '2020-01-28',
#     'release_date_precision': 'day',
#     'total_tracks': 3,
#     'type': 'album',
#     'uri': 'spotify:album:1NqhnYAVqlHuPG2OlgKSZy'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aEnNH9PuU1HF3TsZTru54'},
#      'href': 'https://api.spotify.com/v1/artists/4aEnNH9PuU1HF3TsZTru54',
#      'id': '4aEnNH9PuU1HF3TsZTru54',
#      'name': 'Caribou',
#      'type': 'artist',
#      'uri': 'spotify:artist:4aEnNH9PuU1HF3TsZTru54'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 305480,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DED622000007'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7IBrKDuBlyz3vW9JFCux10'},
#    'href': 'https://api.spotify.com/v1/tracks/7IBrKDuBlyz3vW9JFCux10',
#    'id': '7IBrKDuBlyz3vW9JFCux10',
#    'is_local': False,
#    'name': 'Never Come Back',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7IBrKDuBlyz3vW9JFCux10'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-22T07:36:57Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#    'href': 'https://api.spotify.com/v1/users/gperdigo',
#    'id': 'gperdigo',
#    'type': 'user',
#    'uri': 'spotify:user:gperdigo'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6wH6iStAh4KIaWfuhf0NYM'},
#       'href': 'https://api.spotify.com/v1/artists/6wH6iStAh4KIaWfuhf0NYM',
#       'id': '6wH6iStAh4KIaWfuhf0NYM',
#       'name': 'Manu Chao',
#       'type': 'artist',
#       'uri': 'spotify:artist:6wH6iStAh4KIaWfuhf0NYM'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6sLpbLsD1LlXnlCRjt8YuE'},
#     'href': 'https://api.spotify.com/v1/albums/6sLpbLsD1LlXnlCRjt8YuE',
#     'id': '6sLpbLsD1LlXnlCRjt8YuE',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27381d487c754295e61521aadcc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0281d487c754295e61521aadcc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485181d487c754295e61521aadcc',
#       'width': 64}],
#     'name': 'Proxima Estacion : Esperanza',
#     'release_date': '2001',
#     'release_date_precision': 'year',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:6sLpbLsD1LlXnlCRjt8YuE'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6wH6iStAh4KIaWfuhf0NYM'},
#      'href': 'https://api.spotify.com/v1/artists/6wH6iStAh4KIaWfuhf0NYM',
#      'id': '6wH6iStAh4KIaWfuhf0NYM',
#      'name': 'Manu Chao',
#      'type': 'artist',
#      'uri': 'spotify:artist:6wH6iStAh4KIaWfuhf0NYM'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 114920,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FR84R0100008'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3ecVMxkn0sJ3nlx1uS0IVN'},
#    'href': 'https://api.spotify.com/v1/tracks/3ecVMxkn0sJ3nlx1uS0IVN',
#    'id': '3ecVMxkn0sJ3nlx1uS0IVN',
#    'is_local': False,
#    'name': 'Trapped By Love',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:3ecVMxkn0sJ3nlx1uS0IVN'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-22T07:50:42Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1269546383'},
#    'href': 'https://api.spotify.com/v1/users/1269546383',
#    'id': '1269546383',
#    'type': 'user',
#    'uri': 'spotify:user:1269546383'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v74mT11KGJqadf9sLw4dA'},
#       'href': 'https://api.spotify.com/v1/artists/5v74mT11KGJqadf9sLw4dA',
#       'id': '5v74mT11KGJqadf9sLw4dA',
#       'name': 'Cannonball Adderley',
#       'type': 'artist',
#       'uri': 'spotify:artist:5v74mT11KGJqadf9sLw4dA'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5JpHin9lKOyizuJhKxaHWp'},
#     'href': 'https://api.spotify.com/v1/albums/5JpHin9lKOyizuJhKxaHWp',
#     'id': '5JpHin9lKOyizuJhKxaHWp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27385827d636962ea87b858ab32',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0285827d636962ea87b858ab32',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485185827d636962ea87b858ab32',
#       'width': 64}],
#     'name': 'Jazz Profile: Cannonball Adderley',
#     'release_date': '1997-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 6,
#     'type': 'album',
#     'uri': 'spotify:album:5JpHin9lKOyizuJhKxaHWp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v74mT11KGJqadf9sLw4dA'},
#      'href': 'https://api.spotify.com/v1/artists/5v74mT11KGJqadf9sLw4dA',
#      'id': '5v74mT11KGJqadf9sLw4dA',
#      'name': 'Cannonball Adderley',
#      'type': 'artist',
#      'uri': 'spotify:artist:5v74mT11KGJqadf9sLw4dA'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 313200,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCA29000136'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6NF8MZ2trxckVBr82pyyPt'},
#    'href': 'https://api.spotify.com/v1/tracks/6NF8MZ2trxckVBr82pyyPt',
#    'id': '6NF8MZ2trxckVBr82pyyPt',
#    'is_local': False,
#    'name': 'Mercy, Mercy, Mercy',
#    'popularity': 55,
#    'preview_url': None,
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:6NF8MZ2trxckVBr82pyyPt'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-22T07:51:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1269546383'},
#    'href': 'https://api.spotify.com/v1/users/1269546383',
#    'id': '1269546383',
#    'type': 'user',
#    'uri': 'spotify:user:1269546383'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ayds6VIVBx3CU5NSNCDbq'},
#       'href': 'https://api.spotify.com/v1/artists/3ayds6VIVBx3CU5NSNCDbq',
#       'id': '3ayds6VIVBx3CU5NSNCDbq',
#       'name': 'Jacques Dutronc',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ayds6VIVBx3CU5NSNCDbq'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2S4mgB4hHSszPRGoYrGJ0d'},
#     'href': 'https://api.spotify.com/v1/albums/2S4mgB4hHSszPRGoYrGJ0d',
#     'id': '2S4mgB4hHSszPRGoYrGJ0d',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a28387fcc6e1c7ed11d82022',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a28387fcc6e1c7ed11d82022',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a28387fcc6e1c7ed11d82022',
#       'width': 64}],
#     'name': "L' aventurier",
#     'release_date': '1969-06-30',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:2S4mgB4hHSszPRGoYrGJ0d'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ayds6VIVBx3CU5NSNCDbq'},
#      'href': 'https://api.spotify.com/v1/artists/3ayds6VIVBx3CU5NSNCDbq',
#      'id': '3ayds6VIVBx3CU5NSNCDbq',
#      'name': 'Jacques Dutronc',
#      'type': 'artist',
#      'uri': 'spotify:artist:3ayds6VIVBx3CU5NSNCDbq'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TR',
#     'TT',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 155600,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FRZ196900030'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6FwkZ5lYdCUh1mzI1Bhojn'},
#    'href': 'https://api.spotify.com/v1/tracks/6FwkZ5lYdCUh1mzI1Bhojn',
#    'id': '6FwkZ5lYdCUh1mzI1Bhojn',
#    'is_local': False,
#    'name': 'Le responsable',
#    'popularity': 38,
#    'preview_url': 'https://p.scdn.co/mp3-preview/57a0e4a3ae296a7e3e75205e2d04c76f8394637a?cid=8b2e52a68a1a4cc2bd81cf2503b9466d',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6FwkZ5lYdCUh1mzI1Bhojn'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-22T07:51:17Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1269546383'},
#    'href': 'https://api.spotify.com/v1/users/1269546383',
#    'id': '1269546383',
#    'type': 'user',
#    'uri': 'spotify:user:1269546383'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2AR42Ur9PcchQDtEdwkv4L'},
#       'href': 'https://api.spotify.com/v1/artists/2AR42Ur9PcchQDtEdwkv4L',
#       'id': '2AR42Ur9PcchQDtEdwkv4L',
#       'name': 'Floating Points',
#       'type': 'artist',
#       'uri': 'spotify:artist:2AR42Ur9PcchQDtEdwkv4L'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1WwZwdTICfaZI51BIIEN9z'},
#     'href': 'https://api.spotify.com/v1/albums/1WwZwdTICfaZI51BIIEN9z',
#     'id': '1WwZwdTICfaZI51BIIEN9z',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d03dff7f5eeee485e5a45f62',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d03dff7f5eeee485e5a45f62',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d03dff7f5eeee485e5a45f62',
#       'width': 64}],
#     'name': 'Crush',
#     'release_date': '2019-10-18',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:1WwZwdTICfaZI51BIIEN9z'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2AR42Ur9PcchQDtEdwkv4L'},
#      'href': 'https://api.spotify.com/v1/artists/2AR42Ur9PcchQDtEdwkv4L',
#      'id': '2AR42Ur9PcchQDtEdwkv4L',
#      'name': 'Floating Points',
#      'type': 'artist',
#      'uri': 'spotify:artist:2AR42Ur9PcchQDtEdwkv4L'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
# ...
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0kelpiZssyYlVNks8cHEth'},
#     'href': 'https://api.spotify.com/v1/albums/0kelpiZssyYlVNks8cHEth',
#     'id': '0kelpiZssyYlVNks8cHEth',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734d5ac815f4676b21c60bfdc8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024d5ac815f4676b21c60bfdc8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514d5ac815f4676b21c60bfdc8',
#       'width': 64}],
#     'name': 'Eu Vou Fazer uma Macumba Pra Te Amarrar, Maldito!',
#     'release_date': '2015-02-22',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:0kelpiZssyYlVNks8cHEth'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qmf5YAQYjfjBF9C7kkjzs'},
#      'href': 'https://api.spotify.com/v1/artists/7qmf5YAQYjfjBF9C7kkjzs',
#      'id': '7qmf5YAQYjfjBF9C7kkjzs',
#      'name': 'Johnny Hooker',
#      'type': 'artist',
#      'uri': 'spotify:artist:7qmf5YAQYjfjBF9C7kkjzs'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 285000,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'uscgh1563538'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7uSdpAkxgB0948bW7yjjJO'},
#    'href': 'https://api.spotify.com/v1/tracks/7uSdpAkxgB0948bW7yjjJO',
#    'id': '7uSdpAkxgB0948bW7yjjJO',
#    'is_local': False,
#    'name': 'Amor Marginal',
#    'popularity': 50,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d763ebf13b84079b55cbee99c0c2fb29c0938ff7?cid=8b2e52a68a1a4cc2bd81cf2503b9466d',
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:7uSdpAkxgB0948bW7yjjJO'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-22T07:53:52Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/shokoshock'},
#    'href': 'https://api.spotify.com/v1/users/shokoshock',
#    'id': 'shokoshock',
#    'type': 'user',
#    'uri': 'spotify:user:shokoshock'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YMeriqrS3zgsX24nfY0F0'},
#       'href': 'https://api.spotify.com/v1/artists/0YMeriqrS3zgsX24nfY0F0',
#       'id': '0YMeriqrS3zgsX24nfY0F0',
#       'name': 'The Tragically Hip',
#       'type': 'artist',
#       'uri': 'spotify:artist:0YMeriqrS3zgsX24nfY0F0'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6fRGXiRnTyLLRDXpXkrK1n'},
#     'href': 'https://api.spotify.com/v1/albums/6fRGXiRnTyLLRDXpXkrK1n',
#     'id': '6fRGXiRnTyLLRDXpXkrK1n',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273eb5ebaaa20f7d208ce1caa14',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02eb5ebaaa20f7d208ce1caa14',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851eb5ebaaa20f7d208ce1caa14',
#       'width': 64}],
#     'name': 'Yer Favourites',
#     'release_date': '2005-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 37,
#     'type': 'album',
#     'uri': 'spotify:album:6fRGXiRnTyLLRDXpXkrK1n'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YMeriqrS3zgsX24nfY0F0'},
#      'href': 'https://api.spotify.com/v1/artists/0YMeriqrS3zgsX24nfY0F0',
#      'id': '0YMeriqrS3zgsX24nfY0F0',
#      'name': 'The Tragically Hip',
#      'type': 'artist',
#      'uri': 'spotify:artist:0YMeriqrS3zgsX24nfY0F0'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 225426,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'CAM199600015'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5nC2BQzszGGkZi7cvxFzH4'},
#    'href': 'https://api.spotify.com/v1/tracks/5nC2BQzszGGkZi7cvxFzH4',
#    'id': '5nC2BQzszGGkZi7cvxFzH4',
#    'is_local': False,
#    'name': 'Ahead By A Century',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:5nC2BQzszGGkZi7cvxFzH4'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-22T13:02:30Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/vaxgmeceb7pigybrcc3fdlhiw'},
#    'href': 'https://api.spotify.com/v1/users/vaxgmeceb7pigybrcc3fdlhiw',
#    'id': 'vaxgmeceb7pigybrcc3fdlhiw',
#    'type': 'user',
#    'uri': 'spotify:user:vaxgmeceb7pigybrcc3fdlhiw'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7zsin6IgVsR1rqSRCNYDwq'},
#       'href': 'https://api.spotify.com/v1/artists/7zsin6IgVsR1rqSRCNYDwq',
#       'id': '7zsin6IgVsR1rqSRCNYDwq',
#       'name': 'Family of the Year',
#       'type': 'artist',
#       'uri': 'spotify:artist:7zsin6IgVsR1rqSRCNYDwq'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/14SCnv027L0HidHq0URIDu'},
#     'href': 'https://api.spotify.com/v1/albums/14SCnv027L0HidHq0URIDu',
#     'id': '14SCnv027L0HidHq0URIDu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731980a53c08d4911caa77d249',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021980a53c08d4911caa77d249',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511980a53c08d4911caa77d249',
#       'width': 64}],
#     'name': 'Loma Vista',
#     'release_date': '2012-07-10',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:14SCnv027L0HidHq0URIDu'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7zsin6IgVsR1rqSRCNYDwq'},
#      'href': 'https://api.spotify.com/v1/artists/7zsin6IgVsR1rqSRCNYDwq',
#      'id': '7zsin6IgVsR1rqSRCNYDwq',
#      'name': 'Family of the Year',
#      'type': 'artist',
#      'uri': 'spotify:artist:7zsin6IgVsR1rqSRCNYDwq'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 190280,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'CAN111200237'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6GRDI9suQHikFP6euIXnpq'},
#    'href': 'https://api.spotify.com/v1/tracks/6GRDI9suQHikFP6euIXnpq',
#    'id': '6GRDI9suQHikFP6euIXnpq',
#    'is_local': False,
#    'name': 'Hero',
#    'popularity': 66,
#    'preview_url': 'https://p.scdn.co/mp3-preview/3d1f4e7938a250e489290ca27e1ebc9b511c1cf4?cid=8b2e52a68a1a4cc2bd81cf2503b9466d',
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:6GRDI9suQHikFP6euIXnpq'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-29T14:22:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/8em1nqrnfspx3alyw0rz3ggn1'},
#    'href': 'https://api.spotify.com/v1/users/8em1nqrnfspx3alyw0rz3ggn1',
#    'id': '8em1nqrnfspx3alyw0rz3ggn1',
#    'type': 'user',
#    'uri': 'spotify:user:8em1nqrnfspx3alyw0rz3ggn1'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/58r1rB5t3VF5X6yXGPequV'},
#       'href': 'https://api.spotify.com/v1/artists/58r1rB5t3VF5X6yXGPequV',
#       'id': '58r1rB5t3VF5X6yXGPequV',
#       'name': 'Maverick City Music',
#       'type': 'artist',
#       'uri': 'spotify:artist:58r1rB5t3VF5X6yXGPequV'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0prxUuXzlIyjSJU9ej003n'},
#     'href': 'https://api.spotify.com/v1/albums/0prxUuXzlIyjSJU9ej003n',
#     'id': '0prxUuXzlIyjSJU9ej003n',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732176cda6fb0f4db7dbb6f1fb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022176cda6fb0f4db7dbb6f1fb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512176cda6fb0f4db7dbb6f1fb',
#       'width': 64}],
#     'name': 'Maverick City Vol. 3 Part 1',
#     'release_date': '2020-04-17',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:0prxUuXzlIyjSJU9ej003n'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/58r1rB5t3VF5X6yXGPequV'},
#      'href': 'https://api.spotify.com/v1/artists/58r1rB5t3VF5X6yXGPequV',
#      'id': '58r1rB5t3VF5X6yXGPequV',
#      'name': 'Maverick City Music',
#      'type': 'artist',
#      'uri': 'spotify:artist:58r1rB5t3VF5X6yXGPequV'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5nO7Yt0Jon48sqKR6VME4T'},
#      'href': 'https://api.spotify.com/v1/artists/5nO7Yt0Jon48sqKR6VME4T',
#      'id': '5nO7Yt0Jon48sqKR6VME4T',
#      'name': 'Joe L Barnes',
#      'type': 'artist',
#      'uri': 'spotify:artist:5nO7Yt0Jon48sqKR6VME4T'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4rc8nzClXj7sUjvsHVg6AD'},
#      'href': 'https://api.spotify.com/v1/artists/4rc8nzClXj7sUjvsHVg6AD',
#      'id': '4rc8nzClXj7sUjvsHVg6AD',
#      'name': 'Naomi Raine',
#      'type': 'artist',
#      'uri': 'spotify:artist:4rc8nzClXj7sUjvsHVg6AD'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 646239,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCAET2042835'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0aZFEiDKLK2B4gzPaGCZVm'},
#    'href': 'https://api.spotify.com/v1/tracks/0aZFEiDKLK2B4gzPaGCZVm',
#    'id': '0aZFEiDKLK2B4gzPaGCZVm',
#    'is_local': False,
#    'name': 'Promises',
#    'popularity': 66,
#    'preview_url': None,
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:0aZFEiDKLK2B4gzPaGCZVm'},
#   'video_thumbnail': {'url': None}}]

# %%
len(results)
# Out:
# 4

# %%
uris = []
names = []

for result in results:
    for i in result["items"]:
        uris.append(i["track"]["uri"])
        names.append(i["track"]["name"])

# %%
uris
# Out:
# ['spotify:track:5Tnx4R7Gwj1LZsfssfzchh',
#  'spotify:track:5eKfpH2dQ7FltCqb7LWEGJ',
#  'spotify:track:0R3OcHrzq3f8raukyZgTAc',
#  'spotify:track:24upABZ8A0sAepfu91sEYr',
#  'spotify:track:7IBrKDuBlyz3vW9JFCux10',
#  'spotify:track:3ecVMxkn0sJ3nlx1uS0IVN',
#  'spotify:track:6NF8MZ2trxckVBr82pyyPt',
#  'spotify:track:6FwkZ5lYdCUh1mzI1Bhojn',
#  'spotify:track:75QdM3nsnAluOD19G1J4il',
#  'spotify:track:6Yg3gGtLuZTyZ8i4zGUaJa',
#  'spotify:track:03XkLBYaV5PlgHQYlTEvZm',
#  'spotify:track:6f3Slt0GbA2bPZlz0aIFXN',
#  'spotify:track:7uSdpAkxgB0948bW7yjjJO',
#  'spotify:track:5nC2BQzszGGkZi7cvxFzH4',
#  'spotify:track:6GRDI9suQHikFP6euIXnpq',
#  'spotify:track:0aZFEiDKLK2B4gzPaGCZVm',
#  'spotify:track:5MpayeDmtJwgCpxQOkVBtN',
#  'spotify:track:3jQa7pofP3CHRTt4Xnoyt6',
#  'spotify:track:1SIdietqp8lUZGyeGACpxj',
#  'spotify:track:7g5m83brkyQ3tYXxomx6P2',
#  'spotify:track:51Fi8flrG3IHrFeU4G198k',
#  'spotify:track:6f2QFiiM5mePNlUeHUL3Hh',
#  'spotify:track:2p6qtCgJz42Mae5p4zUwDl',
#  'spotify:track:4pCCSIQzxFsFPakL9LyUbc',
#  'spotify:track:3Xi4Hu8BcUNdUBmBjpkh20',
#  'spotify:track:5dBHELm9dGc3kKsPeYIYKd',
#  'spotify:track:0BrFvLsC8ydsHIz6jghMPo',
#  'spotify:track:2ItBFk9uQHqPyANx8rEUr2',
#  'spotify:track:3LQxLAwCQ7gqzTgiL8oRrh',
#  'spotify:track:7iPfY3lXOMH77BoZstQUhc',
#  'spotify:track:6HnbvDYhRA5E1fItsYnbPQ',
#  'spotify:track:6APIeDnJBcgEFOWv5plRhD',
#  'spotify:track:4YCSXeEYWw1aIF3aNSzl6j',
#  'spotify:track:2VeWXYKHiESWNipFu33QGv',
#  'spotify:track:3BF0S0f1KQNvTd5c9B3E2u',
#  'spotify:track:0LnppLKOrMMbhhauZBBJcQ',
#  'spotify:track:36wB70EUpiU89GF2eLWjfD',
#  'spotify:track:1tj2z0tht71UmMqRqgmH2K',
#  'spotify:track:5X6bt0reZfHUAn0KpBrArf',
#  'spotify:track:5N66DdC8iiowzoR6CDrAii',
#  'spotify:track:5Adxsld8lL9MLcaULeoSKu',
#  'spotify:track:4OlcB3a0LJIrltfQt8vV1S',
#  'spotify:track:5dOnBq60AajXJ9MtOG64FN',
#  'spotify:track:3GW78c0NinQpL8HtzU9X13',
#  'spotify:track:0BcbSvjOZ9dUDmXAcnqmeO',
#  'spotify:track:0niy8sCXnQXc9JZGWWVvLd',
#  'spotify:track:2P9GzQDc9rFeJ0TwY3ewRP',
#  'spotify:track:4QrUtdSJNxBZ11BU0sPa7J',
#  'spotify:track:3d3wW0qalzZdZbFbtSfRWt',
#  'spotify:track:36soyVMvHB2FRb0DgLr9ll',
#  'spotify:track:2Cn9pJmdrntPhYCr9ym5KF',
#  'spotify:track:6s4xgBaxucbNcyVsFmMClO',
#  'spotify:track:7mUR9hqvGLG5XicfVl7gTm',
#  'spotify:track:5hJVLQbPigabZDgZhulWVD',
#  'spotify:track:6kscmCdqAfXzADEXf0VueN',
#  'spotify:track:2gZ0GfJ2aVO7qptKCohWwp',
#  'spotify:track:5AVxVsEjJM144w91gKRdq1',
#  'spotify:track:4L2D6eUEQOdvAyjc0khFAW',
#  'spotify:track:0xlT8eSY5eLdy4S3eyWtNp',
#  'spotify:track:3bnsBfPcpsCT60fs7R2M02',
#  'spotify:track:2nDoc1hwGcNKf8QWCVCeLG',
#  'spotify:track:6oklNuDesCz9yjI2mZdv4B',
#  'spotify:track:6lXC8iSvGz65ZwoZXYKGtj',
#  'spotify:track:50GwMEDGgD1AVVcYXOuAnl',
#  'spotify:track:24aGazQ1aZwIW4B4b98Kr3',
#  'spotify:track:4P0YbSLRJEXvDExPcioMLc',
#  'spotify:track:4z6MjoY4K07vqeI4023U2Q',
#  'spotify:track:3HoO8VUfyXwkgqwaIrVM7u',
#  'spotify:track:6Dkjc0jzDgNtHf6Kr0HTLf',
#  'spotify:track:48qAOahd28j6zuPAWSLZ4K',
#  'spotify:track:4GiHrGKNP80LnTO4xDTX1A',
#  'spotify:track:1uGoNcJCeOz4Y3DHodcjSk',
#  'spotify:track:5QGhn5Z7RRsMKx6hPFOSUO',
#  'spotify:track:2yTjLx8CDh1kpfl9L4XBmI',
#  'spotify:track:0PoKop2ivdajRtzpXbKuyS',
#  'spotify:track:6kfCqm1AIN0zFipPemEbtG',
#  'spotify:track:66ai6JEub08B31JWtBghr6',
#  'spotify:track:30ltN7cC2P6pCueI7aVcxO',
#  'spotify:track:4Z9NjZthRYiY4pjcScpWsc',
#  'spotify:track:4QbU6tZQnsDtyEm35ikBZq',
#  'spotify:track:2nI7rOSYklk4SZ3ccPvG2j',
#  'spotify:track:6xBpeJHE26gAAjgVkCBbzU',
#  'spotify:track:4uxvvTbmuTKJky7w2LVXTW',
#  'spotify:track:7bzE1Y56OWShf2970pBfYM',
#  'spotify:track:56S04BxQD4FsePfNQIt6Cd',
#  'spotify:track:6bnDla4VOr2JBtyK3AeZEJ',
#  'spotify:track:6Esdz6FtuGJaQuJ6rLIUil',
#  'spotify:track:1NY7BwYlCryUbEyXrImFKM',
#  'spotify:track:4c3RWR07IbbOs0FP7Ei6Hd',
#  'spotify:track:3U8Fx7zNTQrctytkj6Gqgd',
#  'spotify:track:1L4NadMj3Jj7YgGaikyhfr',
#  'spotify:track:5xbuJuQsTVheVZvX2AJVIv',
#  'spotify:track:6YDgMoJ8ssOuKjQ6jiz4Kk',
#  'spotify:track:4tKmydUDl8OIeb7fioEsnl',
#  'spotify:track:28XMNc5If5BmJWYDU42gkw',
#  'spotify:track:2d6ml9Qkx8r4EjuUyrdpRV',
#  'spotify:track:1eqyKmkcp7b2s1PU9fEZRS',
#  'spotify:track:3weNRklVDqb4Rr5MhKBR3D',
#  'spotify:track:7N2tmiKcG2bUgZkuRKXor4',
#  'spotify:track:6mfmrVSe5Cm7cvsNwW6uJk',
#  'spotify:track:64LTn5fTsPR0QLy7bVYl9w',
#  'spotify:track:1BncfTJAWxrsxyT9culBrj',
#  'spotify:track:0kckvKwPBjQuVLgwGnICAv',
#  'spotify:track:0U69ZvJfshKs1OVIyW1E7B',
#  'spotify:track:0H2VhGUC3P3hvwz8rdGIpC',
#  'spotify:track:5qVqMPQdfFywNQIOP7Ncdz',
#  'spotify:track:1mlLOJXeUrwviYpUHYeZE8',
#  'spotify:track:0OrZXWjGgGUuoIoqnLvtJN',
#  'spotify:track:3QPPP2YozZ5xmMmpDB3c9n',
#  'spotify:track:1GBUqmdRjScFoG0cs8jEGZ',
#  'spotify:track:4XJXYvjW0CB2MLMk8l7Vdi',
#  'spotify:track:5xm20JNLHy9vUVrnmZS6Uj',
#  'spotify:track:7KrdT8Zk0WGeyNtaCwQR08',
#  'spotify:track:6MgSw0gPRiCeYid2y2BgWS',
#  'spotify:track:1seJCRhM5PqQ5xGebh0iQ0',
#  'spotify:track:1GCpKbwGqAwleD1GK31zT0',
#  'spotify:track:1nPHuiD55BwCjJeUBxDsHd',
#  'spotify:track:41g83Usxjh9TRoxNGGqTTU',
#  'spotify:track:687dYpD7d1LTkxSA4H1Qzd',
#  'spotify:track:0T5p4InF1JeJBYHVU5xvJz',
#  'spotify:track:67XXdBK80hV7APXgWwb3jg',
#  'spotify:track:670kHoKB4WnZCVSJz4ymNx',
#  'spotify:track:7rIWt3zlh2ntF1XDzj3wee',
#  'spotify:track:2XRnbXXt4vdrPdI3QL8Lym',
#  'spotify:track:7lY6qt63y0Ag5lpHMVglLo',
#  'spotify:track:4v3o4IJt1VRDNiM2LCoOXV',
#  'spotify:track:5xVcnhVL0AwcOgbpuxTu6W',
#  'spotify:track:4QfYHdV8hMoyS9qKUct98q',
#  'spotify:track:1hX3yoGAJypm6dMMWLoyKo',
#  'spotify:track:5sztos7ZCFp6Qmk8WvEMZH',
#  'spotify:track:4nd6FMCfNFWkbi2dnsf5I3',
#  'spotify:track:6SAZljHhCrFcqtVe1AQ0ED',
#  'spotify:track:6yjpji2Jlie9S2zBm2GZwE',
#  'spotify:track:3NrOSg735np3PW8OEvt5F8',
#  'spotify:track:5CBzaWVsJgl4DD1oNInz9b',
#  'spotify:track:7zv2BCCUu8bwd9fo9BA8IK',
#  'spotify:track:7cp3lHAPGcUbb7tJP0kuxl',
#  'spotify:track:4Lpe7VxL34rcMnpfOwoqOI',
#  'spotify:track:02xd7yuAEiLOF7rt4zlPep',
#  'spotify:track:58vWVeAtv2LKwlYyRLPWV5',
#  'spotify:track:5wDBBKEIiDYwPQj4SpbBPI',
#  'spotify:track:31BLOz0XDJPPDKI94Gd14v',
#  'spotify:track:1gK2cDl2dY7DFUEXvoMms6',
#  'spotify:track:3vSOD8Ng5m8eLH4EhoJcTL',
#  'spotify:track:33DWEcHqtj1w5rnghLE77x',
#  'spotify:track:4CBIdJ5o1XyMlkUg4jOHWg',
#  'spotify:track:7i9cdG6l1lg0xAraTublsw',
#  'spotify:track:65J9Ep6oWjSgyJ8MFChjWl',
#  'spotify:track:6Ntsj2X8cjYHoG9ykImLsT',
#  'spotify:track:5RWA30VaTsYkFrkzxKL3aK',
#  'spotify:track:1YluEbLfaWBfV2GpQQLOcZ',
#  'spotify:track:5Gm2tHCFTzb0vHZfReSr5f',
#  'spotify:track:0EnEULk14Oso59QtQHVUoC',
#  'spotify:track:2XYEu7Deyz20WeL6Py3XLc',
#  'spotify:track:1fWeZQfdmAoi3HWpHcn4tM',
#  'spotify:track:4cfwFc5ptXuzQMT9fSdnOl',
#  'spotify:track:4DsbdOinvRPoD2ax4DhxMU',
#  'spotify:track:2kAdK72mjmKiAxfAMGgXBU',
#  'spotify:track:0d71p8tQDxLgdTkEHcxQyl',
#  'spotify:track:4i8ly7ffzWu8nfKLI8SZFj',
#  'spotify:track:3z3nJD2LEW3yFMaEjjGerZ',
#  'spotify:track:2ZrF3UfwS50CKE8jQQVjWj',
#  'spotify:track:5zIJsFst05gsrUdr9ghEpG',
#  'spotify:track:4PRnYCH5hoxypKVcOBvx3a',
#  'spotify:track:4ju98rvX917EwXLKLnRbQ2',
#  'spotify:track:6q5co1XdRmnMeWlL1RWXPK',
#  'spotify:track:29T3H5d9TgTlYcKiuNxdRT',
#  'spotify:track:5RqKo9P4DLA0bVyY70cWkr',
#  'spotify:track:43bSKCMWHIuBsUVmQcDX1J',
#  'spotify:track:2Lio4KTzsA8BPLhXmyo4CQ',
#  'spotify:track:4xqay5NL9jPHSCP2mo3U67',
#  'spotify:track:6aANvQTjMgtOlCAaHlYcyn',
#  'spotify:track:0Y9BzZGT2FuLVPrHoq1g2G',
#  'spotify:track:419qlOGNXoyICx4jO0hqaj',
#  'spotify:track:3hCPh4oVVjaM8tv9sFH8cx',
#  'spotify:track:2xU2c2aqQDSHgNGHcQnOj4',
#  'spotify:track:0vzSIBAqnN1HzvWrPbh6VF',
#  'spotify:track:3iWo5Y9DpJNdFI3lERYgEy',
#  'spotify:track:0ftAOThcYwpSDapJhDOy7o',
#  'spotify:track:6Olyr6tQ7DKWPJro6nn35C',
#  'spotify:track:5BRfucuiAf5IYRbwBYBYPZ',
#  'spotify:track:3hgRiVuiBWVbpd4kBQD68m',
#  'spotify:track:6t7lMFHSifu9j8NPMNCv9T',
#  'spotify:track:3lLKvUcryMjlY35OizFKJb',
#  'spotify:track:5xlRxcBGa6RqPRBzKP8fwv',
#  'spotify:track:16xQMSrDSEWP5Lp8GrHGcu',
#  'spotify:track:46tPGzCXCI2oKsemztDA9u',
#  'spotify:track:7pgJTa3eZM4kkT2vsZUmFt',
#  'spotify:track:1k82bzEjGy47GX0EbVPseH',
#  'spotify:track:1BKT2I9x4RGKaKqW4up34s',
#  'spotify:track:7m97yKVzPpXV9Z4ezEziOD',
#  'spotify:track:6jaj4k0LwFLy1q54TXZZpZ',
#  'spotify:track:2ImuQo1g14CTR9hZAZD3aQ',
#  'spotify:track:2TZuNkLb0J6oKLEdlZ0XX3',
#  'spotify:track:740gNyGWKk98gy8nJLhHrv',
#  'spotify:track:67mtN6BlsJR0LVyzvNZnGt',
#  'spotify:track:3IrkbGQCoEPAkzJ0Tkv8nm',
#  'spotify:track:6SuIF8oh96UPJIIJjKvtIe',
#  'spotify:track:7rxeH2yGlCeDKEkNNTpY29',
#  'spotify:track:4Qxv2L4JICAWLFrBV6QeH8',
#  'spotify:track:6VqQjCxM21kapF2RxdTtYA',
#  'spotify:track:7nYvUtkQMx1v80S2FH2s9J',
#  'spotify:track:0ySoJyAbKGLI5yShGBOIQ8',
#  'spotify:track:38XOEv37waF4pd8Ztmna7K',
#  'spotify:track:3WXNzlFDSfjEmNFUOSccf7',
#  'spotify:track:0s46SltT4On0Z6kglK1I5c',
#  'spotify:track:3KKrZ3adgWcJiJQWFqoDnv',
#  'spotify:track:6aJ90LBl96bly9zuEH1U2X',
#  'spotify:track:0W2mz7mvaBaEsC4rmoRNPn',
#  'spotify:track:3eY9pixHny3kVRLeqNezQx',
#  'spotify:track:3F3R4uyTMkX9jRCEVVmdz6',
#  'spotify:track:0LWkaEyQRkF0XAms8Bg1fC',
#  'spotify:track:6Ag4SYLUGFdnJrCwUIb4mT',
#  'spotify:track:17GdAx0kHOFNXZiCj8HuOW',
#  'spotify:track:4EIzsbsVOzfLwyIvfsRQ8H',
#  'spotify:track:4WMBl2wiGUSGa5C7tfQEAo',
#  'spotify:track:2nCVH8UkoII2jWwx6SYVso',
#  'spotify:track:350tsRjB2hVodX7wjCMHcS',
#  'spotify:track:71A6V5dh5Y8ikhm6NGwZ7p',
#  'spotify:track:10EGxvr4fSE42ABWZeJ3K3',
#  'spotify:track:28AvvchUP85ihRe9xCzcfB',
#  'spotify:track:3G0z1kH46uVRqW7f9Qp1OR',
#  'spotify:track:4F4neui0edP1ozygvFiCi7',
#  'spotify:track:1zONdCQrEJ4t3mlzKQADEN',
#  'spotify:track:3cb6gJ7SHYuZ3NVm996ffD',
#  'spotify:track:0Mu1MYdE414HeybYSms5KK',
#  'spotify:track:1FkgoPdajl8gwC1hlyvHtC',
#  'spotify:track:0f1yzIIGD8k32DNVeEn6jb',
#  'spotify:track:7Afjy65bIVBMpFwCLTiuEe',
#  'spotify:track:7aRGb3vZGMLNpK2PEdUjdA',
#  'spotify:track:0ZHu7jkSSrT0eK4OxuG4O5',
#  'spotify:track:7Jc0l11j0Ehx6smWHqDXtX',
#  'spotify:track:0hbSQvosqCvCFaiSRPEUYP',
#  'spotify:track:5JV45IebgbfO3EylYV49rl',
#  'spotify:track:3gKwVWwKmeuFtPubICbOGc',
#  'spotify:track:1yo16b3u0lptm6Cs7lx4AD',
#  'spotify:track:6C7ZgThn6Yan5MTZdAEEFw',
#  'spotify:track:1xZdjsAGrY4BUIbIlYy3EX',
#  'spotify:track:5Tl0HJvynZtKdSUMKbFVVX']

# %%
audio_feat = []

for uri in uris:
    audio_feat.extend(sp.audio_features(uri))

# %%
audiofeat_df = pd.DataFrame(audio_feat)

# %%
audiofeat_df["name"] = names

# %%
cols = audiofeat_df.columns.to_list()

# %%
cols = cols[-1:] + cols[:-1]

# %%
audiofeat_df = audiofeat_df[cols]
audiofeat_df.head()
# Out:
#                                      name  danceability  energy  key  \
# 0  You're the One - From "I Lost My Body"         0.535   0.724    5
# 1                               The Alien         0.464   0.334    6
# 2             Oh, Pecador (Oh, Sinne Man)         0.623   0.239   11
# 3                 Moon (And It Went Like)         0.662   0.657    7
# 4                         Never Come Back         0.776   0.684    5
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -9.905     1       0.0618         0.202          0.901000    0.0983
# 1   -12.916     1       0.0313         0.307          0.247000    0.1100
# 2   -12.638     0       0.0979         0.886          0.000929    0.1710
# 3   -10.002     1       0.0345         0.288          0.856000    0.1020
# 4    -8.934     1       0.0367         0.405          0.559000    0.0663
#
#    valence    tempo            type                      id  \
# 0   0.3700  159.948  audio_features  5Tnx4R7Gwj1LZsfssfzchh
# 1   0.3260  165.278  audio_features  5eKfpH2dQ7FltCqb7LWEGJ
# 2   0.5850  124.485  audio_features  0R3OcHrzq3f8raukyZgTAc
# 3   0.0584  117.986  audio_features  24upABZ8A0sAepfu91sEYr
# 4   0.6550  127.979  audio_features  7IBrKDuBlyz3vW9JFCux10
#
#                                     uri  \
# 0  spotify:track:5Tnx4R7Gwj1LZsfssfzchh
# 1  spotify:track:5eKfpH2dQ7FltCqb7LWEGJ
# 2  spotify:track:0R3OcHrzq3f8raukyZgTAc
# 3  spotify:track:24upABZ8A0sAepfu91sEYr
# 4  spotify:track:7IBrKDuBlyz3vW9JFCux10
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/5Tnx4R7Gwj1L...
# 1  https://api.spotify.com/v1/tracks/5eKfpH2dQ7Fl...
# 2  https://api.spotify.com/v1/tracks/0R3OcHrzq3f8...
# 3  https://api.spotify.com/v1/tracks/24upABZ8A0sA...
# 4  https://api.spotify.com/v1/tracks/7IBrKDuBlyz3...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/5Tnx...       167987
# 1  https://api.spotify.com/v1/audio-analysis/5eKf...       328933
# 2  https://api.spotify.com/v1/audio-analysis/0R3O...       145773
# 3  https://api.spotify.com/v1/audio-analysis/24up...       390639
# 4  https://api.spotify.com/v1/audio-analysis/7IBr...       305480
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
